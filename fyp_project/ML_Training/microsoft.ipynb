# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
import ta
from tabulate import tabulate
from datetime import date

from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# keras Models
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %% [markdown]
# # Data Preparation and Feature Engineering

# %% [markdown]
# ## Data Collection

# %%
# Download historical price data from Yahoo Finance and store it in a pandas DataFrame
df = yf.download("MSFT", start='2020-01-01', end=date.today(), progress=False)

# %% [markdown]
# ## Adding Technical Indicators

# %%
# Add technical indicators
df['SMA_10'] = ta.trend.SMAIndicator(df['Close'], window=10).sma_indicator()
df['EMA_10'] = ta.trend.EMAIndicator(df['Close'], window=10).ema_indicator()
df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=10).rsi()
macd = ta.trend.MACD(df['Close'], window_slow=26, window_fast=12, window_sign=9)
df['MACD'] = macd.macd()
df['MACD_Signal'] = macd.macd_signal()

# %% [markdown]
# ## Adding Lag Features

# %%
# Add lag features, remove missing values, and scale the features
lag_periods = 10  # Number of lag periods for the lag features
for i in range(1, lag_periods + 1):
    df[f'lag_{i}'] = df['Close'].shift(i).values.copy()

# %% [markdown]
# ## Removing Missing Values

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Model Training and Evaluation

# %%
# Define independent variables (features) and target variable
X = df.drop(['Close', 'Adj Close'], axis=1)
y = df['Close']

# # Perform feature selection by selecting features with a correlation coefficient of at least 0.5 with the target variable
corr = X.corrwith(y)
corr_threshold = 0.5
selected_features = corr[abs(corr) > corr_threshold].index.tolist()
X = X[selected_features]

# %% [markdown]
# ## Splitting Data into Training and Testing Sets

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10, shuffle=False)

# %% [markdown]
# ## Feature Scaling

# %%
# Preprocess the data by scaling it
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Training Support Vector Regression (SVR) Model

# %%
# Build SVR model
svr_model = SVR()
svr_model.fit(X_train_scaled, y_train)
# Out:
# SVR()

# %% [markdown]
# ## Training Random Forest Regression (RFR) Model

# %%
# Build RFR model
rfr_model = RandomForestRegressor()
rfr_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Evaluating SVR & RFR Model Performance

# %%
# Evaluate SVR model on training set
y_svr_pred_train = svr_model.predict(X_train_scaled)
r2_svr_train = r2_score(y_train, y_svr_pred_train)
mse_svr_train = mean_squared_error(y_train, y_svr_pred_train)
mae_svr_train = mean_absolute_error(y_train, y_svr_pred_train)

# Evaluate SVR model on testing set
y_svr_pred_test = svr_model.predict(X_test_scaled)
r2_svr_test = r2_score(y_test, y_svr_pred_test)
mse_svr_test = mean_squared_error(y_test, y_svr_pred_test)
mae_svr_test = mean_absolute_error(y_test, y_svr_pred_test)

# Evaluate RFR model on training set
y_rfr_pred_train = rfr_model.predict(X_train_scaled)
r2_rfr_train = r2_score(y_train, y_rfr_pred_train)
mse_rfr_train = mean_squared_error(y_train, y_rfr_pred_train)
mae_rfr_train = mean_absolute_error(y_train, y_rfr_pred_train)

# Evaluate RFR model on testing set
y_rfr_pred_test = rfr_model.predict(X_test_scaled)
r2_rfr_test = r2_score(y_test, y_rfr_pred_test)
mse_rfr_test = mean_squared_error(y_test, y_rfr_pred_test)
mae_rfr_test = mean_absolute_error(y_test, y_rfr_pred_test)

# Create a table to display the evaluation metrics for SVR and RFR models
svr_result = ["SVR", r2_svr_train, r2_svr_test, mse_svr_train, mse_svr_test, mae_svr_train, mae_svr_test]
rfr_result = ["RFR", r2_rfr_train, r2_rfr_test, mse_rfr_train, mse_rfr_test, mae_rfr_train, mae_rfr_test]
result_table = [svr_result, rfr_result]
headers = ["Model", "R² (Train)", "R² (Test)", "MSE (Train)", "MSE (Test)", "MAE (Train)", "MAE (Test)"]

# Print the evaluation metrics table
print(tabulate(result_table, headers=headers, tablefmt="fancy_grid"))
# Out:
# ╒═════════╤══════════════╤═════════════╤═══════════════╤══════════════╤═══════════════╤══════════════╕
# │ Model   │   R² (Train) │   R² (Test) │   MSE (Train) │   MSE (Test) │   MAE (Train) │   MAE (Test) │
# ╞═════════╪══════════════╪═════════════╪═══════════════╪══════════════╪═══════════════╪══════════════╡
# │ SVR     │     0.938083 │    0.910477 │    138.453    │    104.161   │      6.89585  │      6.78714 │
# ├─────────┼──────────────┼─────────────┼───────────────┼──────────────┼───────────────┼──────────────┤
# │ RFR     │     0.999612 │    0.995648 │      0.867437 │      5.06343 │      0.693675 │      1.7794  │
# ╘═════════╧══════════════╧═════════════╧═══════════════╧══════════════╧═══════════════╧══════════════╛

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ## Defining Parameter Grids for SVR and RFR Models

# %%
# Define the parameter grid to search over for SVR model
param_grid_svr = {
    'kernel': ['linear', 'poly', 'rbf'],
    'C': [0.1, 1, 10, 100],
    'gamma': ['auto', 'scale'],
}

# Define the parameter grid to search over for RFR model
param_grid_rfr = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

# %% [markdown]
# ## Performing Grid Search for SVR Model

# %%
# Create a GridSearchCV object with the parameter grid and the SVR model
grid_search_svr = GridSearchCV(
    estimator=SVR(),
    param_grid=param_grid_svr,
    cv=5,
    scoring='r2', 
)

# Fit the GridSearchCV object to the training data
grid_search_svr.fit(X_train_scaled, y_train)

# Get the best SVR model
svr_model = grid_search_svr.best_estimator_

# %% [markdown]
# ## Performing Grid Search for RFR Model

# %%
# Create a GridSearchCV object with the parameter grid and the RFR model
grid_search_rfr = GridSearchCV(
    estimator=RandomForestRegressor(),
    param_grid=param_grid_rfr,
    cv=5,
    scoring='r2',
)

# Fit the GridSearchCV object to the training data
grid_search_rfr.fit(X_train_scaled, y_train)

# Get the best RFR model
rfr_model = grid_search_rfr.best_estimator_

# %% [markdown]
# # Voting Regressor

# %% [markdown]
# ## Creating a Voting Regressor with SVR and RFR Models

# %%
from sklearn.ensemble import VotingRegressor

# Define the ensemble classifier using a VotingClassifier
voting_model = VotingRegressor(
    estimators=[('svm', svr_model), ('rfc', rfr_model)])

# %% [markdown]
# ## Training Voting Regressor

# %%
voting_model.fit(X_train_scaled, y_train)
# Out:
# VotingRegressor(estimators=[('svm', SVR(C=100, gamma='auto', kernel='linear')),
#                             ('rfc',
#                              RandomForestRegressor(min_samples_leaf=4,
#                                                    min_samples_split=5))])

# %% [markdown]
# ## LSTM Model

# %%
from keras.callbacks import EarlyStopping
from keras.regularizers import l1_l2

# # Reshape the input features to fit the LSTM model
X_train_reshaped = np.reshape(X_train_scaled, (X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], X_test_scaled.shape[1], 1))

# Build the LSTM model
lstm_model = Sequential()

lstm_model.add(LSTM(150, return_sequences=True, input_shape=(X_train_scaled.shape[1], 1)))
lstm_model.add(Dropout(0.2))
lstm_model.add(LSTM(150, kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))
lstm_model.add(Dropout(0.2))
lstm_model.add(Dense(1))
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20)

# Train the LSTM model with early stopping
history = lstm_model.fit(X_train_reshaped, y_train, epochs=1000, batch_size=32, validation_data=(X_test_reshaped, y_test))
# Out:
# Epoch 1/1000
# 22/22 [==============================] - 2s 38ms/step - loss: 61204.5469 - val_loss: 65788.1797
# Epoch 2/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 56173.8125 - val_loss: 63805.4453
# Epoch 3/1000
# 22/22 [==============================] - 0s 19ms/step - loss: 54548.2188 - val_loss: 62120.7500
# Epoch 4/1000
# 22/22 [==============================] - 0s 19ms/step - loss: 53021.8320 - val_loss: 60540.2852
# Epoch 5/1000
# 22/22 [==============================] - 0s 19ms/step - loss: 51663.6914 - val_loss: 59035.8711
# Epoch 6/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 50313.1406 - val_loss: 57571.0234
# Epoch 7/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 48948.6641 - val_loss: 56140.3828
# Epoch 8/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 47626.4102 - val_loss: 54736.6523
# Epoch 9/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 46385.9375 - val_loss: 53356.3945
# Epoch 10/1000
# 22/22 [==============================] - 0s 19ms/step - loss: 45075.0273 - val_loss: 52004.9102
# Epoch 11/1000
# 22/22 [==============================] - 0s 19ms/step - loss: 43892.0312 - val_loss: 50665.8750
# Epoch 12/1000
# 22/22 [==============================] - 0s 19ms/step - loss: 42658.1680 - val_loss: 49373.6367
# Epoch 13/1000
# 22/22 [==============================] - 0s 19ms/step - loss: 41512.8203 - val_loss: 48122.8164
# Epoch 14/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 40378.1289 - val_loss: 46856.8047
# Epoch 15/1000
# 22/22 [==============================] - 0s 19ms/step - loss: 39309.5938 - val_loss: 45640.4844
# Epoch 16/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 38185.4062 - val_loss: 44436.4102
# Epoch 17/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 37088.9922 - val_loss: 43270.7734
# Epoch 18/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 36154.1289 - val_loss: 42131.5195
# Epoch 19/1000
# 22/22 [==============================] - 0s 19ms/step - loss: 35082.1172 - val_loss: 41009.7227
# Epoch 20/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 34073.2422 - val_loss: 39908.9062
# Epoch 21/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 33022.3438 - val_loss: 38835.3906
# Epoch 22/1000
# 22/22 [==============================] - 0s 21ms/step - loss: 32136.0625 - val_loss: 37758.6602
# Epoch 23/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 31045.8926 - val_loss: 36716.3008
# Epoch 24/1000
# 22/22 [==============================] - 0s 21ms/step - loss: 30212.0527 - val_loss: 35704.4570
# Epoch 25/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 29350.6152 - val_loss: 34711.6172
# Epoch 26/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 28479.8223 - val_loss: 33752.3281
# Epoch 27/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 27619.0371 - val_loss: 32810.9219
# Epoch 28/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 26868.8438 - val_loss: 31906.3379
# Epoch 29/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 26000.5625 - val_loss: 31009.9785
# Epoch 30/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 25200.8477 - val_loss: 30117.7129
# Epoch 31/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 24520.6973 - val_loss: 29238.2715
# Epoch 32/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 23758.7812 - val_loss: 28385.1621
# Epoch 33/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 22942.8301 - val_loss: 27572.6387
# Epoch 34/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 22284.7129 - val_loss: 26786.2188
# Epoch 35/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 21647.4512 - val_loss: 26002.3730
# Epoch 36/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 20886.4121 - val_loss: 25229.0977
# Epoch 37/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 20222.4922 - val_loss: 24478.5430
# Epoch 38/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 19576.8047 - val_loss: 23756.3008
# Epoch 39/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 18995.1133 - val_loss: 23058.4453
# Epoch 40/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 18484.6797 - val_loss: 22377.9648
# Epoch 41/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 17832.8145 - val_loss: 21720.8613
# Epoch 42/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 17177.7559 - val_loss: 21061.0039
# Epoch 43/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 16623.9258 - val_loss: 20431.4160
# Epoch 44/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 16101.6553 - val_loss: 19806.1934
# Epoch 45/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 15596.6064 - val_loss: 19214.2422
# Epoch 46/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 15030.9609 - val_loss: 18633.5938
# Epoch 47/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 14643.1475 - val_loss: 18070.3320
# Epoch 48/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 14142.1045 - val_loss: 17500.5918
# Epoch 49/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 13662.4502 - val_loss: 16952.9785
# Epoch 50/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 13275.9170 - val_loss: 16419.3105
# Epoch 51/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 12830.8867 - val_loss: 15909.2246
# Epoch 52/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 12433.0176 - val_loss: 15421.9541
# Epoch 53/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 11981.2529 - val_loss: 14942.0283
# Epoch 54/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 11644.1436 - val_loss: 14484.6123
# Epoch 55/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 11173.4268 - val_loss: 14048.7734
# Epoch 56/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 10906.4600 - val_loss: 13620.6865
# Epoch 57/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 10490.9521 - val_loss: 13185.8281
# Epoch 58/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 10207.8145 - val_loss: 12788.9365
# Epoch 59/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 9843.1738 - val_loss: 12389.8730
# Epoch 60/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 9401.4854 - val_loss: 11993.1025
# Epoch 61/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 9153.3467 - val_loss: 11606.3320
# Epoch 62/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 8864.4932 - val_loss: 11229.4844
# Epoch 63/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 8596.0938 - val_loss: 10881.2520
# Epoch 64/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 8460.7344 - val_loss: 10532.5996
# Epoch 65/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 7988.8091 - val_loss: 10192.0479
# Epoch 66/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 7762.9897 - val_loss: 9867.5586
# Epoch 67/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 7588.7852 - val_loss: 9543.9219
# Epoch 68/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 7277.7524 - val_loss: 9250.5469
# Epoch 69/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 7055.9971 - val_loss: 8956.0381
# Epoch 70/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 6813.1821 - val_loss: 8676.4844
# Epoch 71/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 6652.4526 - val_loss: 8390.4736
# Epoch 72/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 6378.1221 - val_loss: 8115.0068
# Epoch 73/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 6335.0132 - val_loss: 7862.3735
# Epoch 74/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 6027.6284 - val_loss: 7624.6182
# Epoch 75/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 5850.4839 - val_loss: 7374.5737
# Epoch 76/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 5664.7339 - val_loss: 7130.8667
# Epoch 77/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 5544.9048 - val_loss: 6901.5044
# Epoch 78/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 5333.6616 - val_loss: 6677.6519
# Epoch 79/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 5224.0454 - val_loss: 6459.9946
# Epoch 80/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 5053.3530 - val_loss: 6262.5386
# Epoch 81/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 4927.3926 - val_loss: 6062.9536
# Epoch 82/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 4770.7939 - val_loss: 5888.8481
# Epoch 83/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 4677.1729 - val_loss: 5714.4888
# Epoch 84/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 4524.2500 - val_loss: 5539.8818
# Epoch 85/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 4393.4590 - val_loss: 5366.1045
# Epoch 86/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 4248.4023 - val_loss: 5189.4507
# Epoch 87/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 4106.8911 - val_loss: 5040.8237
# Epoch 88/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 4076.4294 - val_loss: 4883.9048
# Epoch 89/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3978.4250 - val_loss: 4752.9185
# Epoch 90/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3896.1719 - val_loss: 4629.1978
# Epoch 91/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3820.1758 - val_loss: 4485.6567
# Epoch 92/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3663.9900 - val_loss: 4368.3799
# Epoch 93/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3577.3228 - val_loss: 4253.9487
# Epoch 94/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 3522.9468 - val_loss: 4145.0464
# Epoch 95/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3425.7529 - val_loss: 4022.7083
# Epoch 96/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3378.1973 - val_loss: 3905.9607
# Epoch 97/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 3336.8264 - val_loss: 3801.5591
# Epoch 98/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3215.2073 - val_loss: 3702.5735
# Epoch 99/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3288.8169 - val_loss: 3605.3176
# Epoch 100/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3166.0081 - val_loss: 3512.2844
# Epoch 101/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 3082.8801 - val_loss: 3418.9722
# Epoch 102/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3111.1650 - val_loss: 3331.8499
# Epoch 103/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 3010.4712 - val_loss: 3247.3806
# Epoch 104/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2906.3210 - val_loss: 3166.4690
# Epoch 105/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2918.1401 - val_loss: 3098.4819
# Epoch 106/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2848.8555 - val_loss: 3026.7480
# Epoch 107/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2809.2302 - val_loss: 2957.5476
# Epoch 108/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2831.1914 - val_loss: 2883.1177
# Epoch 109/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2756.3054 - val_loss: 2820.4231
# Epoch 110/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2763.3352 - val_loss: 2756.2246
# Epoch 111/1000
# 22/22 [==============================] - 0s 21ms/step - loss: 2705.1936 - val_loss: 2704.9082
# Epoch 112/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2647.5500 - val_loss: 2649.6711
# Epoch 113/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2674.2917 - val_loss: 2595.7512
# Epoch 114/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2644.7295 - val_loss: 2545.2317
# Epoch 115/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2632.9788 - val_loss: 2494.4678
# Epoch 116/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2525.3826 - val_loss: 2444.8926
# Epoch 117/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2533.2302 - val_loss: 2387.5732
# Epoch 118/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2569.6514 - val_loss: 2344.0325
# Epoch 119/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2561.7429 - val_loss: 2301.7925
# Epoch 120/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2546.2686 - val_loss: 2261.6084
# Epoch 121/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2518.6863 - val_loss: 2218.5247
# Epoch 122/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2483.7258 - val_loss: 2183.8464
# Epoch 123/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2483.2043 - val_loss: 2160.2219
# Epoch 124/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2519.7114 - val_loss: 2138.0425
# Epoch 125/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2487.9404 - val_loss: 2102.4382
# Epoch 126/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2429.6921 - val_loss: 2072.1873
# Epoch 127/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2460.5632 - val_loss: 2047.1215
# Epoch 128/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2494.8633 - val_loss: 2021.4666
# Epoch 129/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2445.3308 - val_loss: 2002.7008
# Epoch 130/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2460.0764 - val_loss: 1980.1552
# Epoch 131/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2373.3591 - val_loss: 1953.2740
# Epoch 132/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2397.1394 - val_loss: 1927.9850
# Epoch 133/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2408.9409 - val_loss: 1904.6498
# Epoch 134/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2342.4924 - val_loss: 1886.0654
# Epoch 135/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2342.7991 - val_loss: 1872.1300
# Epoch 136/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2472.0598 - val_loss: 1860.0050
# Epoch 137/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2401.2744 - val_loss: 1849.8279
# Epoch 138/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2351.3291 - val_loss: 1832.2650
# Epoch 139/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2410.0557 - val_loss: 1819.3402
# Epoch 140/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2446.3125 - val_loss: 1814.1195
# Epoch 141/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2302.1831 - val_loss: 1795.2903
# Epoch 142/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2267.5459 - val_loss: 1786.4601
# Epoch 143/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2353.3120 - val_loss: 1777.0374
# Epoch 144/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2436.9810 - val_loss: 1762.0344
# Epoch 145/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2305.7837 - val_loss: 1817.8214
# Epoch 146/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2436.0486 - val_loss: 2156.3987
# Epoch 147/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2439.6768 - val_loss: 1991.6499
# Epoch 148/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2397.6829 - val_loss: 1960.1512
# Epoch 149/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2387.0776 - val_loss: 1936.1423
# Epoch 150/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2431.9856 - val_loss: 1909.6664
# Epoch 151/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2482.4792 - val_loss: 1880.5879
# Epoch 152/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2388.6335 - val_loss: 1869.7234
# Epoch 153/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2378.1941 - val_loss: 1849.9171
# Epoch 154/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2401.8911 - val_loss: 1823.2841
# Epoch 155/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2373.2876 - val_loss: 1801.7988
# Epoch 156/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2383.4290 - val_loss: 1788.9608
# Epoch 157/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2403.7407 - val_loss: 1774.6964
# Epoch 158/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2405.1304 - val_loss: 1763.7245
# Epoch 159/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2313.9519 - val_loss: 1751.6893
# Epoch 160/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2401.8196 - val_loss: 1741.7684
# Epoch 161/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2342.7932 - val_loss: 1740.1857
# Epoch 162/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2439.2297 - val_loss: 1736.6797
# Epoch 163/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2364.3037 - val_loss: 1730.3179
# Epoch 164/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2316.3804 - val_loss: 1715.2806
# Epoch 165/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2320.3450 - val_loss: 1706.6202
# Epoch 166/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2344.1228 - val_loss: 1687.8271
# Epoch 167/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2358.5786 - val_loss: 1667.8068
# Epoch 168/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2313.9568 - val_loss: 1651.4515
# Epoch 169/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2266.3306 - val_loss: 1647.1949
# Epoch 170/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2307.3062 - val_loss: 1684.6853
# Epoch 171/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2384.1572 - val_loss: 1734.1652
# Epoch 172/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2299.7446 - val_loss: 1712.0529
# Epoch 173/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2474.8208 - val_loss: 1705.8621
# Epoch 174/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2374.0610 - val_loss: 1692.0399
# Epoch 175/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2357.2656 - val_loss: 1674.7600
# Epoch 176/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2341.2744 - val_loss: 1678.8110
# Epoch 177/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2305.5115 - val_loss: 1675.3419
# Epoch 178/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2382.4268 - val_loss: 1668.9985
# Epoch 179/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2425.3118 - val_loss: 1666.0736
# Epoch 180/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2317.4866 - val_loss: 1654.0240
# Epoch 181/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2354.9998 - val_loss: 1652.6121
# Epoch 182/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2329.2424 - val_loss: 1651.1790
# Epoch 183/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2344.5583 - val_loss: 1782.5219
# Epoch 184/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2414.1565 - val_loss: 1797.0115
# Epoch 185/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2389.7429 - val_loss: 1794.9412
# Epoch 186/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2296.6138 - val_loss: 1773.9282
# Epoch 187/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2416.6775 - val_loss: 1766.6221
# Epoch 188/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2386.6145 - val_loss: 1749.1979
# Epoch 189/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2386.3193 - val_loss: 1738.9562
# Epoch 190/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2345.9783 - val_loss: 1725.6049
# Epoch 191/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2419.9895 - val_loss: 1716.1580
# Epoch 192/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2364.2957 - val_loss: 1883.5105
# Epoch 193/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2485.6555 - val_loss: 1863.3093
# Epoch 194/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2355.8157 - val_loss: 1855.5133
# Epoch 195/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2439.5332 - val_loss: 1834.8365
# Epoch 196/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2433.3374 - val_loss: 1815.6156
# Epoch 197/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2407.9348 - val_loss: 1808.2748
# Epoch 198/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2439.3118 - val_loss: 1796.6127
# Epoch 199/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2344.6516 - val_loss: 1780.4565
# Epoch 200/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2431.8289 - val_loss: 1753.6854
# Epoch 201/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2364.9700 - val_loss: 1670.0651
# Epoch 202/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2365.7036 - val_loss: 1667.7080
# Epoch 203/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2324.3716 - val_loss: 1653.2471
# Epoch 204/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2267.7146 - val_loss: 1644.6804
# Epoch 205/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2346.6831 - val_loss: 1632.0801
# Epoch 206/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2301.8323 - val_loss: 1610.8262
# Epoch 207/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2438.3838 - val_loss: 1610.7949
# Epoch 208/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2377.9324 - val_loss: 1613.3441
# Epoch 209/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2315.0796 - val_loss: 1623.2755
# Epoch 210/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2444.6174 - val_loss: 1623.4231
# Epoch 211/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2291.3850 - val_loss: 1616.9681
# Epoch 212/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2452.3367 - val_loss: 1612.1707
# Epoch 213/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2403.3308 - val_loss: 1607.4243
# Epoch 214/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2422.5759 - val_loss: 1607.9332
# Epoch 215/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2333.7822 - val_loss: 1601.6694
# Epoch 216/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2309.1533 - val_loss: 1587.0615
# Epoch 217/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2361.0974 - val_loss: 1576.7367
# Epoch 218/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2342.7146 - val_loss: 1543.5747
# Epoch 219/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2396.2881 - val_loss: 1521.8335
# Epoch 220/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2337.4409 - val_loss: 1529.1045
# Epoch 221/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2379.2979 - val_loss: 1547.3530
# Epoch 222/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2313.5879 - val_loss: 1538.8833
# Epoch 223/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2369.0696 - val_loss: 1596.8325
# Epoch 224/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2393.1394 - val_loss: 1606.8999
# Epoch 225/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2352.4849 - val_loss: 1622.2119
# Epoch 226/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2343.9546 - val_loss: 1617.0468
# Epoch 227/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2382.9626 - val_loss: 1623.1637
# Epoch 228/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2239.5369 - val_loss: 1642.0215
# Epoch 229/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2334.0127 - val_loss: 1648.1321
# Epoch 230/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2303.8003 - val_loss: 1630.9510
# Epoch 231/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2359.4360 - val_loss: 1619.6115
# Epoch 232/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2336.5540 - val_loss: 1611.1566
# Epoch 233/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2351.0347 - val_loss: 1603.1509
# Epoch 234/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2330.5876 - val_loss: 1589.7708
# Epoch 235/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2368.1755 - val_loss: 1582.3610
# Epoch 236/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2419.6052 - val_loss: 1588.5181
# Epoch 237/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2391.0393 - val_loss: 1576.6071
# Epoch 238/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2419.8491 - val_loss: 1566.3699
# Epoch 239/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2367.1956 - val_loss: 1733.8990
# Epoch 240/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2356.6587 - val_loss: 1726.1882
# Epoch 241/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2420.7202 - val_loss: 1865.3767
# Epoch 242/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2365.1494 - val_loss: 1763.4307
# Epoch 243/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2386.9185 - val_loss: 1759.5836
# Epoch 244/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2333.1392 - val_loss: 1719.3469
# Epoch 245/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2317.6868 - val_loss: 1653.4257
# Epoch 246/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2288.7468 - val_loss: 1653.9863
# Epoch 247/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2383.6838 - val_loss: 1655.3352
# Epoch 248/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2382.9202 - val_loss: 1635.0367
# Epoch 249/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2304.7778 - val_loss: 1614.6793
# Epoch 250/1000
# 22/22 [==============================] - 0s 21ms/step - loss: 2335.0117 - val_loss: 1616.3728
# Epoch 251/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2335.6912 - val_loss: 1723.6053
# Epoch 252/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2381.1362 - val_loss: 1971.5126
# Epoch 253/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2333.2612 - val_loss: 1828.7095
# Epoch 254/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2335.3186 - val_loss: 1771.9160
# Epoch 255/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2447.7971 - val_loss: 1915.2548
# Epoch 256/1000
# 22/22 [==============================] - 0s 21ms/step - loss: 3235.5781 - val_loss: 1894.2622
# Epoch 257/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2319.9873 - val_loss: 1700.7019
# Epoch 258/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2431.0850 - val_loss: 1695.7773
# Epoch 259/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2386.8271 - val_loss: 1692.0510
# Epoch 260/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2371.7881 - val_loss: 1686.6718
# Epoch 261/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2314.3218 - val_loss: 1681.5640
# Epoch 262/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2400.0369 - val_loss: 1693.6936
# Epoch 263/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2438.9189 - val_loss: 1677.9004
# Epoch 264/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2401.6367 - val_loss: 1670.8622
# Epoch 265/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2296.5979 - val_loss: 1679.0059
# Epoch 266/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2392.8083 - val_loss: 1678.9583
# Epoch 267/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 2341.2300 - val_loss: 1656.7075
# Epoch 268/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2365.4055 - val_loss: 1637.8499
# Epoch 269/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2345.6943 - val_loss: 1650.0618
# Epoch 270/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2351.9919 - val_loss: 1633.5701
# Epoch 271/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2453.4929 - val_loss: 1640.1753
# Epoch 272/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2393.9138 - val_loss: 1623.3560
# Epoch 273/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2438.3052 - val_loss: 1635.2086
# Epoch 274/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2328.6816 - val_loss: 1638.7446
# Epoch 275/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2403.5146 - val_loss: 1608.0564
# Epoch 276/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2374.2854 - val_loss: 1605.3297
# Epoch 277/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2291.6367 - val_loss: 1605.8135
# Epoch 278/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2356.5625 - val_loss: 1617.8850
# Epoch 279/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2339.1106 - val_loss: 1617.2960
# Epoch 280/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2325.0935 - val_loss: 1609.9918
# Epoch 281/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2355.9121 - val_loss: 1636.0466
# Epoch 282/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2346.6106 - val_loss: 1633.3337
# Epoch 283/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2381.7009 - val_loss: 1599.2080
# Epoch 284/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2373.2981 - val_loss: 1594.9088
# Epoch 285/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2384.7263 - val_loss: 1584.5459
# Epoch 286/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2344.4546 - val_loss: 1578.3715
# Epoch 287/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2350.5176 - val_loss: 1570.0150
# Epoch 288/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2363.5071 - val_loss: 1574.8254
# Epoch 289/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2356.5569 - val_loss: 1586.4501
# Epoch 290/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2402.9500 - val_loss: 1609.8632
# Epoch 291/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2323.4158 - val_loss: 1604.2086
# Epoch 292/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2241.7422 - val_loss: 1551.0083
# Epoch 293/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2306.2170 - val_loss: 1572.4216
# Epoch 294/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2216.9226 - val_loss: 1507.5438
# Epoch 295/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2072.5613 - val_loss: 1498.9109
# Epoch 296/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 1973.8615 - val_loss: 1443.6108
# Epoch 297/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 2313.8623 - val_loss: 1478.5803
# Epoch 298/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2379.7969 - val_loss: 1569.2623
# Epoch 299/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2335.1487 - val_loss: 1572.4020
# Epoch 300/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2373.4084 - val_loss: 1581.8379
# Epoch 301/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2377.5649 - val_loss: 1606.9856
# Epoch 302/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2337.1584 - val_loss: 1586.3580
# Epoch 303/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2370.4731 - val_loss: 1576.4182
# Epoch 304/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2338.7324 - val_loss: 1562.6777
# Epoch 305/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2355.0618 - val_loss: 1553.2502
# Epoch 306/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2384.8958 - val_loss: 1546.2010
# Epoch 307/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2346.3047 - val_loss: 1549.7130
# Epoch 308/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2384.8218 - val_loss: 1540.8311
# Epoch 309/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2372.8145 - val_loss: 1465.7672
# Epoch 310/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2300.5159 - val_loss: 1441.9232
# Epoch 311/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 2143.0408 - val_loss: 1443.0743
# Epoch 312/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 2089.4900 - val_loss: 1481.2384
# Epoch 313/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 1673.9391 - val_loss: 1252.1583
# Epoch 314/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 1517.0031 - val_loss: 1321.1869
# Epoch 315/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 1518.1862 - val_loss: 1277.9490
# Epoch 316/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 1218.8617 - val_loss: 1060.2018
# Epoch 317/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 1034.8092 - val_loss: 993.4775
# Epoch 318/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 1032.5121 - val_loss: 983.5117
# Epoch 319/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 932.0491 - val_loss: 979.0580
# Epoch 320/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 941.7784 - val_loss: 878.4635
# Epoch 321/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 847.4210 - val_loss: 764.4130
# Epoch 322/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 680.9427 - val_loss: 703.2695
# Epoch 323/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 574.8705 - val_loss: 618.6227
# Epoch 324/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 576.5150 - val_loss: 559.6196
# Epoch 325/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 520.8442 - val_loss: 556.6110
# Epoch 326/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 485.5987 - val_loss: 499.2639
# Epoch 327/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 442.4783 - val_loss: 469.6431
# Epoch 328/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 476.0112 - val_loss: 501.9012
# Epoch 329/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 478.8878 - val_loss: 501.3222
# Epoch 330/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 426.7074 - val_loss: 432.8897
# Epoch 331/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 388.0236 - val_loss: 396.6003
# Epoch 332/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 379.9201 - val_loss: 372.7014
# Epoch 333/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 386.3884 - val_loss: 349.3240
# Epoch 334/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 362.5195 - val_loss: 341.1089
# Epoch 335/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 324.2705 - val_loss: 308.3802
# Epoch 336/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 331.4124 - val_loss: 297.7962
# Epoch 337/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 312.4041 - val_loss: 317.7691
# Epoch 338/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 333.2380 - val_loss: 279.1245
# Epoch 339/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 301.4076 - val_loss: 277.2333
# Epoch 340/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 311.3889 - val_loss: 258.7942
# Epoch 341/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 297.0419 - val_loss: 234.1738
# Epoch 342/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 295.0716 - val_loss: 235.8593
# Epoch 343/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 275.2044 - val_loss: 220.9044
# Epoch 344/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 318.6935 - val_loss: 215.1366
# Epoch 345/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 261.3587 - val_loss: 215.8547
# Epoch 346/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 312.1761 - val_loss: 198.3602
# Epoch 347/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 276.5644 - val_loss: 223.8528
# Epoch 348/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 280.9233 - val_loss: 185.3651
# Epoch 349/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 277.0060 - val_loss: 175.1709
# Epoch 350/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 245.7569 - val_loss: 172.3016
# Epoch 351/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 249.2545 - val_loss: 191.5971
# Epoch 352/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 278.5402 - val_loss: 191.7352
# Epoch 353/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 234.5219 - val_loss: 156.3722
# Epoch 354/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 255.8253 - val_loss: 147.7142
# Epoch 355/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 253.0243 - val_loss: 146.4309
# Epoch 356/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 244.0588 - val_loss: 165.4346
# Epoch 357/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 249.9435 - val_loss: 130.6375
# Epoch 358/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 269.1000 - val_loss: 132.1248
# Epoch 359/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 226.7702 - val_loss: 136.1385
# Epoch 360/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 247.6083 - val_loss: 134.4254
# Epoch 361/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 269.5367 - val_loss: 121.6913
# Epoch 362/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 230.7759 - val_loss: 159.7549
# Epoch 363/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 217.0698 - val_loss: 135.5806
# Epoch 364/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 250.4037 - val_loss: 117.5211
# Epoch 365/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 225.7828 - val_loss: 115.6393
# Epoch 366/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 230.8317 - val_loss: 109.6343
# Epoch 367/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 215.2271 - val_loss: 111.1212
# Epoch 368/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 230.9127 - val_loss: 101.0990
# Epoch 369/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 227.5031 - val_loss: 97.8455
# Epoch 370/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 204.2736 - val_loss: 118.3227
# Epoch 371/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 221.3029 - val_loss: 91.9683
# Epoch 372/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 202.3102 - val_loss: 96.9776
# Epoch 373/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 256.8481 - val_loss: 109.9840
# Epoch 374/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 223.2879 - val_loss: 103.5060
# Epoch 375/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 224.2346 - val_loss: 99.2392
# Epoch 376/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 207.2124 - val_loss: 86.9633
# Epoch 377/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 225.9928 - val_loss: 88.5256
# Epoch 378/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 204.5192 - val_loss: 103.0006
# Epoch 379/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 218.0110 - val_loss: 93.1027
# Epoch 380/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 208.7193 - val_loss: 76.8287
# Epoch 381/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 189.6042 - val_loss: 106.8450
# Epoch 382/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 231.2385 - val_loss: 86.9267
# Epoch 383/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 209.7216 - val_loss: 74.9272
# Epoch 384/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 194.9102 - val_loss: 73.8179
# Epoch 385/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 199.0843 - val_loss: 69.3607
# Epoch 386/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 205.3508 - val_loss: 61.7863
# Epoch 387/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 209.6083 - val_loss: 64.8049
# Epoch 388/1000
# 22/22 [==============================] - 1s 25ms/step - loss: 214.6311 - val_loss: 65.1590
# Epoch 389/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 185.9419 - val_loss: 66.4868
# Epoch 390/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 212.2641 - val_loss: 63.8628
# Epoch 391/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 252.9917 - val_loss: 154.5147
# Epoch 392/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 208.2191 - val_loss: 70.2110
# Epoch 393/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 196.7093 - val_loss: 77.2747
# Epoch 394/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 213.4492 - val_loss: 99.3363
# Epoch 395/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 213.6018 - val_loss: 80.7170
# Epoch 396/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 204.9404 - val_loss: 76.3442
# Epoch 397/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 202.7739 - val_loss: 123.2057
# Epoch 398/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 223.7481 - val_loss: 131.8094
# Epoch 399/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 225.9180 - val_loss: 118.8416
# Epoch 400/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 207.0069 - val_loss: 83.8272
# Epoch 401/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 211.7458 - val_loss: 60.9739
# Epoch 402/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 199.5661 - val_loss: 51.8592
# Epoch 403/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 198.6579 - val_loss: 50.0021
# Epoch 404/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 210.3307 - val_loss: 57.5305
# Epoch 405/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 201.5580 - val_loss: 48.1209
# Epoch 406/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 184.7215 - val_loss: 63.0997
# Epoch 407/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 202.1436 - val_loss: 55.2002
# Epoch 408/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 176.4130 - val_loss: 64.7205
# Epoch 409/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 194.2623 - val_loss: 43.8420
# Epoch 410/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 196.7180 - val_loss: 42.0229
# Epoch 411/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 177.2231 - val_loss: 43.7417
# Epoch 412/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 171.4540 - val_loss: 41.5650
# Epoch 413/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 182.0799 - val_loss: 40.7556
# Epoch 414/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 193.3016 - val_loss: 52.2379
# Epoch 415/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 190.8118 - val_loss: 83.9883
# Epoch 416/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 183.5710 - val_loss: 42.1300
# Epoch 417/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 176.8975 - val_loss: 43.9336
# Epoch 418/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 203.1685 - val_loss: 54.0346
# Epoch 419/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 189.5876 - val_loss: 39.4366
# Epoch 420/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 200.3077 - val_loss: 36.6531
# Epoch 421/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 177.6292 - val_loss: 43.9634
# Epoch 422/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 186.3801 - val_loss: 36.9521
# Epoch 423/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 233.5165 - val_loss: 41.6761
# Epoch 424/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 200.5877 - val_loss: 47.7367
# Epoch 425/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 196.5349 - val_loss: 62.4420
# Epoch 426/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 194.1620 - val_loss: 53.8118
# Epoch 427/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 180.7393 - val_loss: 42.3769
# Epoch 428/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 188.0770 - val_loss: 37.0101
# Epoch 429/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 188.1861 - val_loss: 52.9123
# Epoch 430/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 181.2798 - val_loss: 34.2971
# Epoch 431/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 190.3927 - val_loss: 65.7130
# Epoch 432/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 194.3720 - val_loss: 50.4864
# Epoch 433/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 195.7333 - val_loss: 38.1483
# Epoch 434/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 163.0210 - val_loss: 55.1116
# Epoch 435/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 172.1396 - val_loss: 35.4037
# Epoch 436/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 168.4383 - val_loss: 53.4722
# Epoch 437/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 180.8301 - val_loss: 33.4997
# Epoch 438/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 179.4158 - val_loss: 35.2082
# Epoch 439/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 154.9598 - val_loss: 34.9973
# Epoch 440/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 205.3466 - val_loss: 52.9421
# Epoch 441/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 208.7602 - val_loss: 31.7530
# Epoch 442/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 191.6683 - val_loss: 42.6448
# Epoch 443/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 198.8719 - val_loss: 43.2422
# Epoch 444/1000
# ...
# 22/22 [==============================] - 1s 24ms/step - loss: 227.0683 - val_loss: 66.6078
# Epoch 851/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 178.8810 - val_loss: 44.8455
# Epoch 852/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 168.9183 - val_loss: 43.6634
# Epoch 853/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 155.6520 - val_loss: 31.3976
# Epoch 854/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 172.7555 - val_loss: 37.9018
# Epoch 855/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 173.1932 - val_loss: 33.7514
# Epoch 856/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 182.2964 - val_loss: 30.7718
# Epoch 857/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 170.8729 - val_loss: 54.7352
# Epoch 858/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 162.3903 - val_loss: 43.3044
# Epoch 859/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 169.8694 - val_loss: 27.3023
# Epoch 860/1000
# 22/22 [==============================] - 1s 25ms/step - loss: 173.6895 - val_loss: 30.5194
# Epoch 861/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 155.6473 - val_loss: 31.3470
# Epoch 862/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 149.0417 - val_loss: 25.5860
# Epoch 863/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 161.6850 - val_loss: 34.8151
# Epoch 864/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 163.0977 - val_loss: 31.5478
# Epoch 865/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 162.7370 - val_loss: 25.2299
# Epoch 866/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 160.1124 - val_loss: 44.8031
# Epoch 867/1000
# 22/22 [==============================] - 1s 25ms/step - loss: 178.6592 - val_loss: 83.0486
# Epoch 868/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 189.7258 - val_loss: 37.0028
# Epoch 869/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 168.6233 - val_loss: 25.8016
# Epoch 870/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 173.8035 - val_loss: 30.1528
# Epoch 871/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 145.2663 - val_loss: 27.2009
# Epoch 872/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 148.7228 - val_loss: 30.4904
# Epoch 873/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 156.6805 - val_loss: 26.2316
# Epoch 874/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 152.4174 - val_loss: 26.1298
# Epoch 875/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 167.9075 - val_loss: 27.5528
# Epoch 876/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 172.1206 - val_loss: 27.2057
# Epoch 877/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 164.7599 - val_loss: 26.3536
# Epoch 878/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 161.6075 - val_loss: 45.5791
# Epoch 879/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 170.4986 - val_loss: 29.0021
# Epoch 880/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 173.9072 - val_loss: 53.6138
# Epoch 881/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 141.2325 - val_loss: 22.8027
# Epoch 882/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 157.4848 - val_loss: 22.4822
# Epoch 883/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 151.4284 - val_loss: 30.0504
# Epoch 884/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 147.9166 - val_loss: 35.9329
# Epoch 885/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 149.5490 - val_loss: 25.3223
# Epoch 886/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 162.6423 - val_loss: 32.1653
# Epoch 887/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 151.0025 - val_loss: 22.6877
# Epoch 888/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 164.3531 - val_loss: 33.4887
# Epoch 889/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 149.6381 - val_loss: 22.1704
# Epoch 890/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 137.2671 - val_loss: 30.5338
# Epoch 891/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 175.4940 - val_loss: 21.6553
# Epoch 892/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 156.6456 - val_loss: 26.8030
# Epoch 893/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 158.2071 - val_loss: 41.3991
# Epoch 894/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 147.6470 - val_loss: 23.3209
# Epoch 895/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 173.9539 - val_loss: 23.9084
# Epoch 896/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 156.6858 - val_loss: 48.0323
# Epoch 897/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 162.6982 - val_loss: 20.7541
# Epoch 898/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 164.5846 - val_loss: 20.7884
# Epoch 899/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 151.1994 - val_loss: 19.9561
# Epoch 900/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 144.9882 - val_loss: 32.5298
# Epoch 901/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 141.1966 - val_loss: 24.2597
# Epoch 902/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 147.9528 - val_loss: 35.7603
# Epoch 903/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 152.5336 - val_loss: 35.3271
# Epoch 904/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 155.9537 - val_loss: 30.4281
# Epoch 905/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 145.3258 - val_loss: 24.3442
# Epoch 906/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 150.8910 - val_loss: 29.2931
# Epoch 907/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 151.8824 - val_loss: 23.2050
# Epoch 908/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 150.3185 - val_loss: 19.9034
# Epoch 909/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 151.0430 - val_loss: 20.4952
# Epoch 910/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 158.5114 - val_loss: 21.7442
# Epoch 911/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 173.0050 - val_loss: 19.9512
# Epoch 912/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 168.1568 - val_loss: 29.6787
# Epoch 913/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 143.8022 - val_loss: 30.6995
# Epoch 914/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 175.9533 - val_loss: 22.7729
# Epoch 915/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 152.1188 - val_loss: 22.1045
# Epoch 916/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 142.8304 - val_loss: 23.9768
# Epoch 917/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 145.4562 - val_loss: 36.6695
# Epoch 918/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 169.8757 - val_loss: 26.1371
# Epoch 919/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 155.2041 - val_loss: 20.4734
# Epoch 920/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 148.8279 - val_loss: 30.7385
# Epoch 921/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 154.3870 - val_loss: 19.6535
# Epoch 922/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 172.5178 - val_loss: 21.9741
# Epoch 923/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 145.7030 - val_loss: 32.1506
# Epoch 924/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 143.3948 - val_loss: 19.6027
# Epoch 925/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 159.9460 - val_loss: 32.9236
# Epoch 926/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 160.7479 - val_loss: 54.9108
# Epoch 927/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 181.2836 - val_loss: 60.0765
# Epoch 928/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 142.5431 - val_loss: 25.6980
# Epoch 929/1000
# 22/22 [==============================] - 1s 25ms/step - loss: 154.1260 - val_loss: 33.9738
# Epoch 930/1000
# 22/22 [==============================] - 0s 22ms/step - loss: 164.3227 - val_loss: 20.4642
# Epoch 931/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 153.3530 - val_loss: 22.6866
# Epoch 932/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 143.5734 - val_loss: 19.1699
# Epoch 933/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 132.2027 - val_loss: 20.9071
# Epoch 934/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 134.6912 - val_loss: 32.8937
# Epoch 935/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 169.6311 - val_loss: 20.9598
# Epoch 936/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 143.8512 - val_loss: 31.9326
# Epoch 937/1000
# 22/22 [==============================] - 1s 23ms/step - loss: 135.2834 - val_loss: 24.1094
# Epoch 938/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 143.7221 - val_loss: 23.7175
# Epoch 939/1000
# 22/22 [==============================] - 1s 24ms/step - loss: 150.7195 - val_loss: 29.5447
# Epoch 940/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 138.7350 - val_loss: 19.7798
# Epoch 941/1000
# 22/22 [==============================] - 0s 23ms/step - loss: 135.6853 - val_loss: 30.4905
# Epoch 942/1000
# 22/22 [==============================] - 0s 21ms/step - loss: 143.4759 - val_loss: 46.4066
# Epoch 943/1000
# 22/22 [==============================] - 0s 21ms/step - loss: 156.8718 - val_loss: 17.8748
# Epoch 944/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 160.9199 - val_loss: 27.3875
# Epoch 945/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 149.5565 - val_loss: 72.4806
# Epoch 946/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 147.8334 - val_loss: 30.0058
# Epoch 947/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 152.5085 - val_loss: 48.5114
# Epoch 948/1000
# 22/22 [==============================] - 0s 21ms/step - loss: 182.5074 - val_loss: 52.2316
# Epoch 949/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 143.9552 - val_loss: 45.6225
# Epoch 950/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 163.2431 - val_loss: 20.5231
# Epoch 951/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 152.0082 - val_loss: 29.3528
# Epoch 952/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 165.3066 - val_loss: 18.1247
# Epoch 953/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 171.5004 - val_loss: 26.1151
# Epoch 954/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 149.1472 - val_loss: 20.2597
# Epoch 955/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 173.7880 - val_loss: 43.4849
# Epoch 956/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 136.8789 - val_loss: 21.5808
# Epoch 957/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 139.1229 - val_loss: 22.7707
# Epoch 958/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 192.4656 - val_loss: 55.1327
# Epoch 959/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 165.8402 - val_loss: 33.2980
# Epoch 960/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 157.2196 - val_loss: 34.2257
# Epoch 961/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 145.3526 - val_loss: 25.7952
# Epoch 962/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 151.3027 - val_loss: 24.7835
# Epoch 963/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 163.6237 - val_loss: 24.2529
# Epoch 964/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 164.6584 - val_loss: 43.7807
# Epoch 965/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 164.3496 - val_loss: 23.6847
# Epoch 966/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 198.7601 - val_loss: 37.3041
# Epoch 967/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 161.9308 - val_loss: 27.9866
# Epoch 968/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 162.6951 - val_loss: 37.0954
# Epoch 969/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 146.0860 - val_loss: 19.7875
# Epoch 970/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 160.9400 - val_loss: 49.0464
# Epoch 971/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 155.3575 - val_loss: 21.9411
# Epoch 972/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 155.6656 - val_loss: 20.0507
# Epoch 973/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 135.7172 - val_loss: 21.0691
# Epoch 974/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 150.9308 - val_loss: 28.5541
# Epoch 975/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 158.7155 - val_loss: 18.9333
# Epoch 976/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 145.6610 - val_loss: 28.1050
# Epoch 977/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 175.0718 - val_loss: 20.2271
# Epoch 978/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 150.0622 - val_loss: 33.0221
# Epoch 979/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 165.0953 - val_loss: 24.5696
# Epoch 980/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 145.7817 - val_loss: 19.3869
# Epoch 981/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 159.7255 - val_loss: 24.3320
# Epoch 982/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 137.1111 - val_loss: 24.4763
# Epoch 983/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 153.0153 - val_loss: 22.2977
# Epoch 984/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 151.1679 - val_loss: 19.4942
# Epoch 985/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 147.4752 - val_loss: 29.9933
# Epoch 986/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 141.7462 - val_loss: 19.2327
# Epoch 987/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 141.0908 - val_loss: 21.8653
# Epoch 988/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 140.8018 - val_loss: 33.9568
# Epoch 989/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 152.1361 - val_loss: 18.3432
# Epoch 990/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 149.9580 - val_loss: 24.6060
# Epoch 991/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 160.1350 - val_loss: 23.9854
# Epoch 992/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 150.3825 - val_loss: 43.5152
# Epoch 993/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 151.8882 - val_loss: 49.4355
# Epoch 994/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 177.8898 - val_loss: 20.1169
# Epoch 995/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 133.4827 - val_loss: 17.3536
# Epoch 996/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 150.6961 - val_loss: 19.0465
# Epoch 997/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 138.7063 - val_loss: 26.0629
# Epoch 998/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 172.2701 - val_loss: 22.2218
# Epoch 999/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 166.4781 - val_loss: 22.3962
# Epoch 1000/1000
# 22/22 [==============================] - 0s 20ms/step - loss: 148.4229 - val_loss: 21.9852

# %%
import matplotlib.pyplot as plt

# Get the training and validation loss from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Create a plot of the training and validation loss
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Final Evaluation and Forecasting

# %% [markdown]
# ## Evaluating Final Models (SVR, RFR, Voting)

# %%
# SVR Train Score
y_svr_pred_train = svr_model.predict(X_train_scaled)
r2_svr_train = r2_score(y_train, y_svr_pred_train)
mse_svr_train = mean_squared_error(y_train, y_svr_pred_train)
mae_svr_train = mean_absolute_error(y_train, y_svr_pred_train)

# SVR Test Score
y_svr_pred_test = svr_model.predict(X_test_scaled)
r2_svr_test = r2_score(y_test, y_svr_pred_test)
mse_svr_test = mean_squared_error(y_test, y_svr_pred_test)
mae_svr_test = mean_absolute_error(y_test, y_svr_pred_test)

# RFR Train Score
y_rfr_pred_train = rfr_model.predict(X_train_scaled)
r2_rfr_train = r2_score(y_train, y_rfr_pred_train)
mse_rfr_train = mean_squared_error(y_train, y_rfr_pred_train)
mae_rfr_train = mean_absolute_error(y_train, y_rfr_pred_train)

# RFR Test Score
y_rfr_pred_test = rfr_model.predict(X_test_scaled)
r2_rfr_test = r2_score(y_test, y_rfr_pred_test)
mse_rfr_test = mean_squared_error(y_test, y_rfr_pred_test)
mae_rfr_test = mean_absolute_error(y_test, y_rfr_pred_test)

# Voting Train Score
y_voting_pred_train = voting_model.predict(X_train_scaled)
r2_voting_train = r2_score(y_train, y_voting_pred_train)
mse_voting_train = mean_squared_error(y_train, y_voting_pred_train)
mae_voting_train = mean_absolute_error(y_train, y_voting_pred_train)

# Voting Test Score
y_voting_pred_test = voting_model.predict(X_test_scaled)
r2_voting_test = r2_score(y_test, y_voting_pred_test)
mse_voting_test = mean_squared_error(y_test, y_voting_pred_test)
mae_voting_test = mean_absolute_error(y_test, y_voting_pred_test)

# LSTM Train Score
y_lstm_pred_train = lstm_model.predict(X_train_reshaped)
r2_lstm_train = r2_score(y_train, y_lstm_pred_train)
mse_lstm_train = mean_squared_error(y_train, y_lstm_pred_train)
mae_lstm_train = mean_absolute_error(y_train, y_lstm_pred_train)

# LSTM Test Score
y_lstm_pred_test = lstm_model.predict(X_test_reshaped)
r2_lstm_test = r2_score(y_test, y_lstm_pred_test)
mse_lstm_test = mean_squared_error(y_test, y_lstm_pred_test)
mae_lstm_test = mean_absolute_error(y_test, y_lstm_pred_test)

svr_result = ["SVR (Best)", r2_svr_train, r2_svr_test, mse_svr_train,
            mse_svr_test, mae_svr_train, mae_svr_test]

rfr_result = ["RFR (Best)", r2_rfr_train, r2_rfr_test, mse_rfr_train,
            mse_rfr_test, mae_rfr_train, mae_rfr_test]

voting_result = ["Voting", r2_voting_train, r2_voting_test, mse_voting_train,
            mse_voting_test, mae_voting_train, mae_voting_test]

lstm_result = ["LSTM", r2_lstm_train, r2_lstm_test, mse_lstm_train,
            mse_lstm_test, mae_lstm_train, mae_lstm_test]


result_table = [svr_result, rfr_result, voting_result, lstm_result]
headers = ["Model", "R² (Train)", "R² (Test)","MSE (Train)", "MSE (Test)", "MAE (Train)", "MAE (Test)"]

print(tabulate(result_table, headers=headers, tablefmt="fancy_grid"))
# Out:
# 22/22 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# ╒════════════╤══════════════╤═════════════╤═══════════════╤══════════════╤═══════════════╤══════════════╕
# │ Model      │   R² (Train) │   R² (Test) │   MSE (Train) │   MSE (Test) │   MAE (Train) │   MAE (Test) │
# ╞════════════╪══════════════╪═════════════╪═══════════════╪══════════════╪═══════════════╪══════════════╡
# │ SVR (Best) │     0.998708 │    0.997523 │       2.88959 │      2.88254 │       1.27527 │      1.36884 │
# ├────────────┼──────────────┼─────────────┼───────────────┼──────────────┼───────────────┼──────────────┤
# │ RFR (Best) │     0.99909  │    0.995472 │       2.03515 │      5.26873 │       1.06643 │      1.8313  │
# ├────────────┼──────────────┼─────────────┼───────────────┼──────────────┼───────────────┼──────────────┤
# │ Voting     │     0.999038 │    0.996989 │       2.15172 │      3.50389 │       1.11108 │      1.51414 │
# ├────────────┼──────────────┼─────────────┼───────────────┼──────────────┼───────────────┼──────────────┤
# │ LSTM       │     0.992349 │    0.98598  │      17.1094  │     16.3128  │       3.22435 │      3.12124 │
# ╘════════════╧══════════════╧═════════════╧═══════════════╧══════════════╧═══════════════╧══════════════╛

# %% [markdown]
# ## Cross-Validation

# %%
# # Perform cross-validation
# # Define the scoring metrics
# scoring = ['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2']

# # Perform cross-validation and calculate the mean and standard deviation for each scoring metric
# cv_results = []

# svr_cv_results = ['SVR']
# rfr_cv_results = ['RFR']
# voting_cv_results = ['Voting']
# lstm_cv_results = ['LSTM']

# for score in scoring:
#     svr_cv_scores = cross_val_score(svr_model, X, y, cv=5, scoring=score)
#     rfr_cv_scores = cross_val_score(rfr_model, X, y, cv=5, scoring=score)
#     voting_cv_scores = cross_val_score(voting_model, X, y, cv=5, scoring=score)

#     if score == 'r2':
#         svr_cv_results.append(svr_cv_scores.mean())
#         svr_cv_results.append(svr_cv_scores.std())

#         rfr_cv_results.append(rfr_cv_scores.mean())
#         rfr_cv_results.append(rfr_cv_scores.std())

#         voting_cv_results.append(voting_cv_scores.mean())
#         voting_cv_results.append(voting_cv_scores.std())
#     else:
#         svr_cv_results.append(np.abs(svr_cv_scores).mean())
#         rfr_cv_results.append(np.abs(rfr_cv_scores).mean())
#         voting_cv_results.append(np.abs(voting_cv_scores).mean())

# # Define the number of folds for cross-validation
# n_splits = 5

# # Initialize arrays to store the scores
# mse_scores = []
# mae_scores = []
# r2_scores = []

# # Perform cross-validation
# kf = KFold(n_splits=n_splits)

# for train_index, test_index in kf.split(X):

#     X_train_lstm, X_test_lstm = X.iloc[train_index], X.iloc[test_index]
#     y_train_lstm, y_test_lstm = y[train_index], y[test_index]

#      # Perform feature scaling on the training and validation sets separately
#     X_test_lstm_scaled = scaler.transform(X_test_lstm)
#     X_test_lstm_reshaped =  np.reshape(X_test_lstm_scaled, (X_test_lstm_scaled.shape[0], X_test_lstm_scaled.shape[1], 1))

#     # Evaluate the pre-trained model on the test data
#     y_pred_lstm = lstm_model.predict(X_test_lstm_reshaped)

#     # Calculate the scores for different metrics
#     mse = mean_squared_error(y_test_lstm, y_pred_lstm)
#     mae = mean_absolute_error(y_test_lstm, y_pred_lstm)
#     r2 = r2_score(y_test_lstm, y_pred_lstm)

#     # Append the scores to the respective arrays
#     mse_scores.append(mse)
#     mae_scores.append(mae)
#     r2_scores.append(r2)

# # Calculate the mean and standard deviation of MSE, MAE, and R^2 scores
# mean_mse = np.mean(mse_scores)
# mean_mae = np.mean(mae_scores)
# mean_r2 = np.mean(r2_scores)
# std_r2 = np.std(r2_scores)

# lstm_cv_results.append(mean_mse)
# lstm_cv_results.append(mean_mae)
# lstm_cv_results.append(mean_r2)
# lstm_cv_results.append(std_r2)

# cv_results.extend([svr_cv_results, rfr_cv_results, voting_cv_results, lstm_cv_results])

# # Create a table to display the cross-validation results
# cv_headers = ["Model", "Mean MSE Score", "Mean MAE Score", "Mean R² Score", "R² Standard Deviation"]
# print(tabulate(cv_results, headers=cv_headers, tablefmt="fancy_grid"))
# Out:
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# ╒═════════╤══════════════════╤══════════════════╤═════════════════╤═════════════════════════╕
# │ Model   │   Mean MSE Score │   Mean MAE Score │   Mean R² Score │   R² Standard Deviation │
# ╞═════════╪══════════════════╪══════════════════╪═════════════════╪═════════════════════════╡
# │ SVR     │         267.824  │         12.2637  │        0.446335 │               0.334081  │
# ├─────────┼──────────────────┼──────────────────┼─────────────────┼─────────────────────────┤
# │ RFR     │         143.812  │          5.26536 │        0.711938 │               0.542782  │
# ├─────────┼──────────────────┼──────────────────┼─────────────────┼─────────────────────────┤
# │ Voting  │         116.463  │          7.61025 │        0.764103 │               0.224515  │
# ├─────────┼──────────────────┼──────────────────┼─────────────────┼─────────────────────────┤
# │ LSTM    │          16.9528 │          3.20375 │        0.963501 │               0.0133916 │
# ╘═════════╧══════════════════╧══════════════════╧═════════════════╧═════════════════════════╛

# %% [markdown]
# ## Downloading Latest Historical Price Data

# %% [markdown]
# ## Preparing Forecast Data

# %%
last_index_date = df.index[-1]
start_index_date = df.tail(60).index

# Download latest 60 days historical price data from Yahoo Finance and store in a pandas DataFrame
df_actual = yf.download("MSFT", start=start_index_date[0], end=last_index_date, progress=False)

number_of_days = len(df_actual)
last_n_days = df[-number_of_days:]

last_n_days_df = pd.DataFrame(
    last_n_days, columns=X.columns)

X_pred = scaler.transform(last_n_days_df)

y_svr_pred = svr_model.predict(X_pred) 
y_rfr_pred = rfr_model.predict(X_pred)
y_voting_pred = voting_model.predict(X_pred) 

X_pred_reshaped = np.reshape(X_pred, (X_pred.shape[0], X_pred.shape[1], 1))
y_lstm_pred = lstm_model.predict(X_pred_reshaped)

df_pred = pd.DataFrame({'SVR Prediction': y_svr_pred,
                        'RFR Prediction': y_rfr_pred,
                        'Voting Prediction': y_voting_pred,
                        'LSTM Prediction': np.squeeze(y_lstm_pred)}, index=df_actual.index)

df_combined = pd.concat([df_actual, df_pred], axis=1)

forecast_dates = pd.date_range(start=df.index[-1] + pd.DateOffset(days=1), periods=10, freq='B')
df_forecast = pd.DataFrame(index=forecast_dates)

# Get the last available historical data
last_data = X.iloc[-10:, :]  # Get the last 35 data points, assuming each row represents a sample

# Preprocess the forecast data by scaling it using the same scaler used for training
last_data_scaled = scaler.transform(last_data)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %% [markdown]
# ## Making Predictions for Forecast Period using Final Models

# %%
# Make predictions for the forecast period using the SVR and RFR models
svr_prediction = svr_model.predict(last_data_scaled)
rfr_prediction = rfr_model.predict(last_data_scaled)
voting_prediction = voting_model.predict(last_data_scaled)

last_data_scaled_reshaped = np.reshape(last_data_scaled, (last_data_scaled.shape[0], last_data_scaled.shape[1], 1))
lstm_prediction= lstm_model.predict(last_data_scaled_reshaped)

# Assign the forecasted prices to the DataFrame columns
df_forecast['SVR Prediction'] = svr_prediction
df_forecast['RFR Prediction'] = rfr_prediction
df_forecast['Voting Prediction'] = voting_prediction
df_forecast['LSTM Prediction'] = lstm_prediction

# Set the display format for float values
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
# 1/1 [==============================] - 0s 14ms/step

# %% [markdown]
# ## Combining Actual Prices and Forecasted Prices from all models

# %%
df_combined2 = pd.concat([df_combined, df_forecast])

# %% [markdown]
# ## Visualizing Actual Prices and Predictions

# %%
# Plot the actual price and the predictions
plt.figure(figsize=(16, 8))
plt.plot(df_combined2.index, df_combined2['Close'], label='Historical')
plt.plot(df_combined2.index,
        df_combined2['SVR Prediction'], label='SVR Prediction')
plt.plot(df_combined2.index,
        df_combined2['RFR Prediction'], label='RFR Prediction')
plt.plot(df_combined2.index,
        df_combined2['Voting Prediction'], label='Voting Prediction')
plt.plot(df_combined2.index,
        df_combined2['LSTM Prediction'], label='LSTM Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Displaying Forecasted Prices from all models

# %%
# Assuming df_forecast is your DataFrame
table = tabulate(df_forecast, headers='keys', tablefmt='fancy_grid')
print(table)
# Out:
# ╒═════════════════════╤══════════════════╤══════════════════╤═════════════════════╤═══════════════════╕
# │                     │   SVR Prediction │   RFR Prediction │   Voting Prediction │   LSTM Prediction │
# ╞═════════════════════╪══════════════════╪══════════════════╪═════════════════════╪═══════════════════╡
# │ 2023-06-26 00:00:00 │          327.614 │          330.16  │             329.036 │           331.239 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-06-27 00:00:00 │          328.495 │          330.64  │             329.76  │           332.168 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-06-28 00:00:00 │          333.449 │          334.645 │             333.927 │           333.447 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-06-29 00:00:00 │          336.656 │          335.289 │             335.844 │           333.669 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-06-30 00:00:00 │          345.722 │          340.87  │             343.348 │           334.547 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-03 00:00:00 │          344.386 │          340.885 │             342.707 │           335.307 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-04 00:00:00 │          338.33  │          340.375 │             339.384 │           334.31  │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-05 00:00:00 │          334.114 │          334.94  │             334.619 │           333.797 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-06 00:00:00 │          338.511 │          338.572 │             338.423 │           333.824 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-07 00:00:00 │          336.014 │          336.334 │             336.248 │           333.742 │
# ╘═════════════════════╧══════════════════╧══════════════════╧═════════════════════╧═══════════════════╛

# %%
import plotly.graph_objects as go

# Create traces
trace_actual = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['Close'],
    mode='lines',
    name='Historical'
)

trace_svr = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['SVR Prediction'],
    mode='lines',
    name='SVR Prediction'
)

trace_rfr = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['RFR Prediction'],
    mode='lines',
    name='RFR Prediction'
)

trace_voting = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['Voting Prediction'],
    mode='lines',
    name='Voting Prediction'
)

trace_lstm = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['LSTM Prediction'],
    mode='lines',
    name='LSTM Prediction'
)

data = [trace_actual, trace_svr, trace_rfr, trace_voting, trace_lstm]

# Create layout
layout = go.Layout(
    title='Actual Price and Predictions',
    xaxis=dict(title='Date'),
    yaxis=dict(title='Price'),
    showlegend=True
)

# Create figure
fig = go.Figure(data=data, layout=layout)

# Show the figure
fig.show()

# %%
import pickle

with open('../dashboard/models/microsoft/rfr.pkl', 'wb') as f:
    pickle.dump(rfr_model, f)

with open('../dashboard/models/microsoft/svr.pkl', 'wb') as f:
    pickle.dump(svr_model, f)

with open('../dashboard/models/microsoft/voting.pkl', 'wb') as f:
    pickle.dump(voting_model, f)

with open('../dashboard/models/microsoft/lstm.pkl', 'wb') as f:
    pickle.dump(lstm_model, f)

with open('../dashboard/models/microsoft/scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

df.to_csv('../dashboard/models/microsoft/df.csv', index=True)
X.to_csv('../dashboard/models/microsoft/X.csv', index=True)
