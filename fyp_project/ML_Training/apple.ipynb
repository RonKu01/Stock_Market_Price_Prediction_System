# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
import ta
from tabulate import tabulate
from datetime import date

from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# keras Models
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %% [markdown]
# # Data Preparation and Feature Engineering

# %% [markdown]
# ## Data Collection

# %%
# Download historical price data from Yahoo Finance and store it in a pandas DataFrame
df = yf.download("AAPL", start='2018-01-01', end=date.today(), progress=False)

# %% [markdown]
# ## Adding Technical Indicators

# %%
# Add technical indicators
df['SMA_10'] = ta.trend.SMAIndicator(df['Close'], window=10).sma_indicator()
df['EMA_10'] = ta.trend.EMAIndicator(df['Close'], window=10).ema_indicator()
df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=10).rsi()
macd = ta.trend.MACD(df['Close'], window_slow=26, window_fast=12, window_sign=9)
df['MACD'] = macd.macd()
df['MACD_Signal'] = macd.macd_signal()

# %% [markdown]
# ## Adding Lag Features

# %%
# Add lag features, remove missing values, and scale the features
lag_periods = 10  # Number of lag periods for the lag features
for i in range(1, lag_periods + 1):
    df[f'lag_{i}'] = df['Close'].shift(i).values.copy()

# %% [markdown]
# ## Removing Missing Values

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Model Training and Evaluation

# %%
# Define independent variables (features) and target variable
X = df.drop(['Close', 'Adj Close'], axis=1)
y = df['Close']

# # Perform feature selection by selecting features with a correlation coefficient of at least 0.5 with the target variable
corr = X.corrwith(y)
corr_threshold = 0.5
selected_features = corr[abs(corr) > corr_threshold].index.tolist()
X = X[selected_features]

# %% [markdown]
# ## Splitting Data into Training and Testing Sets

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10, shuffle=False)

# %% [markdown]
# ## Feature Scaling

# %%
# Preprocess the data by scaling it
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Training Support Vector Regression (SVR) Model

# %%
# Build SVR model
svr_model = SVR()
svr_model.fit(X_train_scaled, y_train)
# Out:
# SVR()

# %% [markdown]
# ## Training Random Forest Regression (RFR) Model

# %%
# Build RFR model
rfr_model = RandomForestRegressor()
rfr_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Evaluating SVR & RFR Model Performance

# %%
# Evaluate SVR model on training set
y_svr_pred_train = svr_model.predict(X_train_scaled)
r2_svr_train = r2_score(y_train, y_svr_pred_train)
mse_svr_train = mean_squared_error(y_train, y_svr_pred_train)
mae_svr_train = mean_absolute_error(y_train, y_svr_pred_train)

# Evaluate SVR model on testing set
y_svr_pred_test = svr_model.predict(X_test_scaled)
r2_svr_test = r2_score(y_test, y_svr_pred_test)
mse_svr_test = mean_squared_error(y_test, y_svr_pred_test)
mae_svr_test = mean_absolute_error(y_test, y_svr_pred_test)

# Evaluate RFR model on training set
y_rfr_pred_train = rfr_model.predict(X_train_scaled)
r2_rfr_train = r2_score(y_train, y_rfr_pred_train)
mse_rfr_train = mean_squared_error(y_train, y_rfr_pred_train)
mae_rfr_train = mean_absolute_error(y_train, y_rfr_pred_train)

# Evaluate RFR model on testing set
y_rfr_pred_test = rfr_model.predict(X_test_scaled)
r2_rfr_test = r2_score(y_test, y_rfr_pred_test)
mse_rfr_test = mean_squared_error(y_test, y_rfr_pred_test)
mae_rfr_test = mean_absolute_error(y_test, y_rfr_pred_test)

# Create a table to display the evaluation metrics for SVR and RFR models
svr_result = ["SVR", r2_svr_train, r2_svr_test, mse_svr_train, mse_svr_test, mae_svr_train, mae_svr_test]
rfr_result = ["RFR", r2_rfr_train, r2_rfr_test, mse_rfr_train, mse_rfr_test, mae_rfr_train, mae_rfr_test]
result_table = [svr_result, rfr_result]
headers = ["Model", "R² (Train)", "R² (Test)", "MSE (Train)", "MSE (Test)", "MAE (Train)", "MAE (Test)"]

# Print the evaluation metrics table
print(tabulate(result_table, headers=headers, tablefmt="fancy_grid"))
# Out:
# ╒═════════╤══════════════╤═════════════╤═══════════════╤══════════════╤═══════════════╤══════════════╕
# │ Model   │   R² (Train) │   R² (Test) │   MSE (Train) │   MSE (Test) │   MAE (Train) │   MAE (Test) │
# ╞═════════╪══════════════╪═════════════╪═══════════════╪══════════════╪═══════════════╪══════════════╡
# │ SVR     │     0.994287 │    0.793622 │     11.5031   │     41.0263  │       2.18975 │      4.43349 │
# ├─────────┼──────────────┼─────────────┼───────────────┼──────────────┼───────────────┼──────────────┤
# │ RFR     │     0.999916 │    0.983849 │      0.168817 │      3.21075 │       0.27235 │      1.28287 │
# ╘═════════╧══════════════╧═════════════╧═══════════════╧══════════════╧═══════════════╧══════════════╛

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ## Defining Parameter Grids for SVR and RFR Models

# %%
# Define the parameter grid to search over for SVR model
param_grid_svr = {
    'kernel': ['linear', 'poly', 'rbf'],
    'C': [0.1, 1, 10, 100],
    'gamma': ['auto', 'scale'],
}

# Define the parameter grid to search over for RFR model
param_grid_rfr = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

# %% [markdown]
# ## Performing Grid Search for SVR Model

# %%
# Create a GridSearchCV object with the parameter grid and the SVR model
grid_search_svr = GridSearchCV(
    estimator=SVR(),
    param_grid=param_grid_svr,
    cv=5,
    scoring='r2', 
)

# Fit the GridSearchCV object to the training data
grid_search_svr.fit(X_train_scaled, y_train)

# Get the best SVR model
svr_model = grid_search_svr.best_estimator_

# %% [markdown]
# ## Performing Grid Search for RFR Model

# %%
# Create a GridSearchCV object with the parameter grid and the RFR model
grid_search_rfr = GridSearchCV(
    estimator=RandomForestRegressor(),
    param_grid=param_grid_rfr,
    cv=5,
    scoring='r2',
)

# Fit the GridSearchCV object to the training data
grid_search_rfr.fit(X_train_scaled, y_train)

# Get the best RFR model
rfr_model = grid_search_rfr.best_estimator_

# %% [markdown]
# # Voting Regressor

# %% [markdown]
# ## Creating a Voting Regressor with SVR and RFR Models

# %%
from sklearn.ensemble import VotingRegressor

# Define the ensemble classifier using a VotingClassifier
voting_model = VotingRegressor(
    estimators=[('svm', svr_model), ('rfc', rfr_model)])

# %% [markdown]
# ## Training Voting Regressor

# %%
voting_model.fit(X_train_scaled, y_train)
# Out:
# VotingRegressor(estimators=[('svm', SVR(C=100, gamma='auto', kernel='linear')),
#                             ('rfc', RandomForestRegressor())])

# %% [markdown]
# ## LSTM Model

# %%
# Reshape the input features to fit the LSTM model
X_train_reshaped = np.reshape(X_train_scaled, (X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
X_test_reshaped = np.reshape(X_test_scaled, (X_test_scaled.shape[0], X_test_scaled.shape[1], 1))

# Build the LSTM model
lstm_model = Sequential()

lstm_model.add(LSTM(150, return_sequences=True, input_shape=(X_train_scaled.shape[1], 1)))
lstm_model.add(Dropout(0.2))  # Add a dropout layer with a dropout rate of 0.2
lstm_model.add(LSTM(150))
lstm_model.add(Dropout(0.2))  # Add a dropout layer with a dropout rate of 0.2
lstm_model.add(Dense(1))
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the LSTM model
history = lstm_model.fit(X_train_reshaped, y_train, epochs=1000, batch_size=32)
# Out:
# Epoch 1/1000
# 34/34 [==============================] - 2s 18ms/step - loss: 8740.6113
# Epoch 2/1000
# 34/34 [==============================] - 1s 17ms/step - loss: 7144.4834
# Epoch 3/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 6436.0723
# Epoch 4/1000
# 34/34 [==============================] - 1s 17ms/step - loss: 5825.7173
# Epoch 5/1000
# 34/34 [==============================] - 1s 17ms/step - loss: 5287.0312
# Epoch 6/1000
# 34/34 [==============================] - 1s 17ms/step - loss: 4825.6113
# Epoch 7/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 4386.4878
# Epoch 8/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 4035.7830
# Epoch 9/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 3706.6152
# Epoch 10/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 3445.7104
# Epoch 11/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 3199.4385
# Epoch 12/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2990.0317
# Epoch 13/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2810.8784
# Epoch 14/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2664.5115
# Epoch 15/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2540.8010
# Epoch 16/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2444.9814
# Epoch 17/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2359.6023
# Epoch 18/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2290.1624
# Epoch 19/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2233.9263
# Epoch 20/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2200.0510
# Epoch 21/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2143.7905
# Epoch 22/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2118.6685
# Epoch 23/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2095.3774
# Epoch 24/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2088.0161
# Epoch 25/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2077.2202
# Epoch 26/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2062.0066
# Epoch 27/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2048.2324
# Epoch 28/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2021.3076
# Epoch 29/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2037.6433
# Epoch 30/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2053.8723
# Epoch 31/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2028.3112
# Epoch 32/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2033.9814
# Epoch 33/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2040.0327
# Epoch 34/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2008.7124
# Epoch 35/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2021.4275
# Epoch 36/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2032.9656
# Epoch 37/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2033.6978
# Epoch 38/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2031.1062
# Epoch 39/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2028.4146
# Epoch 40/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2041.6260
# Epoch 41/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2024.6083
# Epoch 42/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2010.2242
# Epoch 43/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2021.2574
# Epoch 44/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2013.1910
# Epoch 45/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2030.3973
# Epoch 46/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2041.9287
# Epoch 47/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2029.9990
# Epoch 48/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2030.2844
# Epoch 49/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2008.7358
# Epoch 50/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2031.1245
# Epoch 51/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2036.8848
# Epoch 52/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2056.2002
# Epoch 53/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2015.4972
# Epoch 54/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2040.9949
# Epoch 55/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2036.1671
# Epoch 56/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2032.3271
# Epoch 57/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2008.6597
# Epoch 58/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2019.1180
# Epoch 59/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2028.7942
# Epoch 60/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2041.4844
# Epoch 61/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2030.3729
# Epoch 62/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2043.9578
# Epoch 63/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2040.9696
# Epoch 64/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2019.6312
# Epoch 65/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2037.4509
# Epoch 66/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2038.3619
# Epoch 67/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2015.3306
# Epoch 68/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2032.6805
# Epoch 69/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2018.2616
# Epoch 70/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2017.8824
# Epoch 71/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2040.8766
# Epoch 72/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2014.1387
# Epoch 73/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2040.9658
# Epoch 74/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2033.4396
# Epoch 75/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2050.4460
# Epoch 76/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2030.6150
# Epoch 77/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2014.3455
# Epoch 78/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2027.4907
# Epoch 79/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2024.2874
# Epoch 80/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2032.0304
# Epoch 81/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2025.6543
# Epoch 82/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2050.9946
# Epoch 83/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2030.2465
# Epoch 84/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2030.0511
# Epoch 85/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2042.6266
# Epoch 86/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2028.2963
# Epoch 87/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2031.2507
# Epoch 88/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2013.4771
# Epoch 89/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2033.1143
# Epoch 90/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2014.1160
# Epoch 91/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2023.3351
# Epoch 92/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2024.9310
# Epoch 93/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2010.2637
# Epoch 94/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2009.4219
# Epoch 95/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2049.2952
# Epoch 96/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2036.9581
# Epoch 97/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2018.0857
# Epoch 98/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2023.9357
# Epoch 99/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2027.4373
# Epoch 100/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2034.4054
# Epoch 101/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2029.5771
# Epoch 102/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2020.3444
# Epoch 103/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2030.4247
# Epoch 104/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2022.6412
# Epoch 105/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2038.5936
# Epoch 106/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2024.0746
# Epoch 107/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2030.9224
# Epoch 108/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2010.6617
# Epoch 109/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2002.8987
# Epoch 110/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2038.9354
# Epoch 111/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2020.1528
# Epoch 112/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2037.4108
# Epoch 113/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2027.1891
# Epoch 114/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2015.4586
# Epoch 115/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2027.2593
# Epoch 116/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2042.8167
# Epoch 117/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2029.3521
# Epoch 118/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2024.3657
# Epoch 119/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2011.2679
# Epoch 120/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 1951.6006
# Epoch 121/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2017.3948
# Epoch 122/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 2019.1378
# Epoch 123/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 1777.7531
# Epoch 124/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 946.1640
# Epoch 125/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 668.3198
# Epoch 126/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 515.0426
# Epoch 127/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 408.2605
# Epoch 128/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 325.7389
# Epoch 129/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 283.3499
# Epoch 130/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 234.2154
# Epoch 131/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 208.3504
# Epoch 132/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 187.9975
# Epoch 133/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 158.5176
# Epoch 134/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 140.2832
# Epoch 135/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 121.2640
# Epoch 136/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 119.2991
# Epoch 137/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 102.9964
# Epoch 138/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 93.9473
# Epoch 139/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 86.7865
# Epoch 140/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 78.2089
# Epoch 141/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 79.2062
# Epoch 142/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 77.7677
# Epoch 143/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 64.1040
# Epoch 144/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 64.5550
# Epoch 145/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 56.8352
# Epoch 146/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 57.3446
# Epoch 147/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 54.9201
# Epoch 148/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 53.4993
# Epoch 149/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 51.9525
# Epoch 150/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 53.8386
# Epoch 151/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 46.7511
# Epoch 152/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 46.1097
# Epoch 153/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 43.4632
# Epoch 154/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 47.3302
# Epoch 155/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 40.6894
# Epoch 156/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 40.6529
# Epoch 157/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 41.4186
# Epoch 158/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 39.1991
# Epoch 159/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 39.0328
# Epoch 160/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 39.1972
# Epoch 161/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 38.2629
# Epoch 162/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 36.4558
# Epoch 163/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 37.3517
# Epoch 164/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 38.4305
# Epoch 165/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 38.0635
# Epoch 166/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 34.5907
# Epoch 167/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.9121
# Epoch 168/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 33.9169
# Epoch 169/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 32.4831
# Epoch 170/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.7967
# Epoch 171/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.0390
# Epoch 172/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 31.6142
# Epoch 173/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 32.4269
# Epoch 174/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.9393
# Epoch 175/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 31.2137
# Epoch 176/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 36.1165
# Epoch 177/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 37.1170
# Epoch 178/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 29.7810
# Epoch 179/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.7132
# Epoch 180/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.0673
# Epoch 181/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 34.3601
# Epoch 182/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.6962
# Epoch 183/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 32.7195
# Epoch 184/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 31.2275
# Epoch 185/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.7702
# Epoch 186/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 30.2275
# Epoch 187/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.1916
# Epoch 188/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.9870
# Epoch 189/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.4526
# Epoch 190/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 33.0912
# Epoch 191/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.8875
# Epoch 192/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.7313
# Epoch 193/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 33.2006
# Epoch 194/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.6707
# Epoch 195/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8507
# Epoch 196/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 31.1103
# Epoch 197/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 31.3465
# Epoch 198/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.5070
# Epoch 199/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.2738
# Epoch 200/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 32.2476
# Epoch 201/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 31.2440
# Epoch 202/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.0096
# Epoch 203/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.7934
# Epoch 204/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.5279
# Epoch 205/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.8488
# Epoch 206/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.4276
# Epoch 207/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 31.8416
# Epoch 208/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.1302
# Epoch 209/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.6351
# Epoch 210/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.4715
# Epoch 211/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.0595
# Epoch 212/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.7571
# Epoch 213/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.9023
# Epoch 214/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.6630
# Epoch 215/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 26.6696
# Epoch 216/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.9111
# Epoch 217/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.5758
# Epoch 218/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.6591
# Epoch 219/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.0515
# Epoch 220/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8094
# Epoch 221/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.8750
# Epoch 222/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.5323
# Epoch 223/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.1954
# Epoch 224/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.9348
# Epoch 225/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.6711
# Epoch 226/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.8976
# Epoch 227/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.7259
# Epoch 228/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.6570
# Epoch 229/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.3285
# Epoch 230/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.5570
# Epoch 231/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.6729
# Epoch 232/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.1443
# Epoch 233/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.1547
# Epoch 234/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.1295
# Epoch 235/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8600
# Epoch 236/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.8158
# Epoch 237/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 26.7441
# Epoch 238/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 27.7431
# Epoch 239/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 31.6169
# Epoch 240/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.0752
# Epoch 241/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 28.4992
# Epoch 242/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.7091
# Epoch 243/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.4728
# Epoch 244/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.0478
# Epoch 245/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8347
# Epoch 246/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.9030
# Epoch 247/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 26.4563
# Epoch 248/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.5544
# Epoch 249/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.8565
# Epoch 250/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.2311
# Epoch 251/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 26.6833
# Epoch 252/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5772
# Epoch 253/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.4008
# Epoch 254/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.3570
# Epoch 255/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 27.0465
# Epoch 256/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.3169
# Epoch 257/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.7915
# Epoch 258/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.0275
# Epoch 259/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.3110
# Epoch 260/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.9699
# Epoch 261/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.3034
# Epoch 262/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.1431
# Epoch 263/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5181
# Epoch 264/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4978
# Epoch 265/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6400
# Epoch 266/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.3554
# Epoch 267/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.4204
# Epoch 268/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3478
# Epoch 269/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8717
# Epoch 270/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1953
# Epoch 271/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 30.0155
# Epoch 272/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.9245
# Epoch 273/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.2051
# Epoch 274/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6355
# Epoch 275/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 30.6158
# Epoch 276/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.9611
# Epoch 277/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.1360
# Epoch 278/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8472
# Epoch 279/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.3387
# Epoch 280/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.0208
# Epoch 281/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1101
# Epoch 282/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8197
# Epoch 283/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.2473
# Epoch 284/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.9125
# Epoch 285/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.1800
# Epoch 286/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 25.8757
# Epoch 287/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.4572
# Epoch 288/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.2408
# Epoch 289/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.5189
# Epoch 290/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.3425
# Epoch 291/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.5780
# Epoch 292/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.5882
# Epoch 293/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.7186
# Epoch 294/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.4106
# Epoch 295/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.0022
# Epoch 296/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 22.8346
# Epoch 297/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.1952
# Epoch 298/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.2565
# Epoch 299/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.7051
# Epoch 300/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.2217
# Epoch 301/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6379
# Epoch 302/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.2327
# Epoch 303/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3911
# Epoch 304/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.7483
# Epoch 305/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1261
# Epoch 306/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.2604
# Epoch 307/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.7954
# Epoch 308/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8233
# Epoch 309/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 25.4219
# Epoch 310/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.3006
# Epoch 311/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6286
# Epoch 312/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3969
# Epoch 313/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.0646
# Epoch 314/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.1384
# Epoch 315/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.3716
# Epoch 316/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.3697
# Epoch 317/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3110
# Epoch 318/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.3463
# Epoch 319/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.2616
# Epoch 320/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.0690
# Epoch 321/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.0012
# Epoch 322/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8908
# Epoch 323/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.7580
# Epoch 324/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.9366
# Epoch 325/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8786
# Epoch 326/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.5937
# Epoch 327/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.2648
# Epoch 328/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.1634
# Epoch 329/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.0046
# Epoch 330/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6725
# Epoch 331/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.5177
# Epoch 332/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.2049
# Epoch 333/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6618
# Epoch 334/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.6872
# Epoch 335/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.2793
# Epoch 336/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3446
# Epoch 337/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8526
# Epoch 338/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.9963
# Epoch 339/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1985
# Epoch 340/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 37.0716
# Epoch 341/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.5796
# Epoch 342/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.5960
# Epoch 343/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 29.2509
# Epoch 344/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.1700
# Epoch 345/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.6965
# Epoch 346/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 25.7505
# Epoch 347/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.9926
# Epoch 348/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6247
# Epoch 349/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.7498
# Epoch 350/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 26.0500
# Epoch 351/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1021
# Epoch 352/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.0306
# Epoch 353/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8699
# Epoch 354/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.2145
# Epoch 355/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3148
# Epoch 356/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.5368
# Epoch 357/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.5171
# Epoch 358/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.6289
# Epoch 359/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.7012
# Epoch 360/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.1539
# Epoch 361/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.1529
# Epoch 362/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.9760
# Epoch 363/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3146
# Epoch 364/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.8810
# Epoch 365/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2380
# Epoch 366/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1707
# Epoch 367/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.9747
# Epoch 368/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6432
# Epoch 369/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5608
# Epoch 370/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.0112
# Epoch 371/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8130
# Epoch 372/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1958
# Epoch 373/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.5469
# Epoch 374/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.6950
# Epoch 375/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.2100
# Epoch 376/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8288
# Epoch 377/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2518
# Epoch 378/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.7380
# Epoch 379/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.8530
# Epoch 380/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9468
# Epoch 381/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.3413
# Epoch 382/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.0622
# Epoch 383/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.4826
# Epoch 384/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1955
# Epoch 385/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.7832
# Epoch 386/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4719
# Epoch 387/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0912
# Epoch 388/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8493
# Epoch 389/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.4578
# Epoch 390/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8983
# Epoch 391/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.4280
# Epoch 392/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.4575
# Epoch 393/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.0387
# Epoch 394/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1938
# Epoch 395/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.0268
# Epoch 396/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6321
# Epoch 397/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3494
# Epoch 398/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4587
# Epoch 399/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9627
# Epoch 400/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.8572
# Epoch 401/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.3907
# Epoch 402/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5983
# Epoch 403/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.4625
# Epoch 404/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 26.1035
# Epoch 405/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.2833
# Epoch 406/1000
# 34/34 [==============================] - 1s 20ms/step - loss: 21.9184
# Epoch 407/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 25.2002
# Epoch 408/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.2610
# Epoch 409/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1024
# Epoch 410/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 25.0086
# Epoch 411/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.0533
# Epoch 412/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6232
# Epoch 413/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.5021
# Epoch 414/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1823
# Epoch 415/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.8613
# Epoch 416/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 25.6573
# Epoch 417/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.0462
# Epoch 418/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9341
# Epoch 419/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 24.8415
# Epoch 420/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 29.8795
# Epoch 421/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 24.2866
# Epoch 422/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 22.0611
# Epoch 423/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.3750
# Epoch 424/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.5933
# Epoch 425/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2968
# Epoch 426/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8035
# Epoch 427/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.2511
# Epoch 428/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.3009
# Epoch 429/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.0677
# Epoch 430/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.7138
# Epoch 431/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1567
# Epoch 432/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6296
# Epoch 433/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.3719
# Epoch 434/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5357
# Epoch 435/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6001
# Epoch 436/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1962
# Epoch 437/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5910
# Epoch 438/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.8422
# Epoch 439/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8112
# Epoch 440/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.2972
# Epoch 441/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.5924
# Epoch 442/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.4378
# Epoch 443/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.6830
# Epoch 444/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.0793
# Epoch 445/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.3922
# Epoch 446/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.1310
# Epoch 447/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.1711
# Epoch 448/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.0599
# Epoch 449/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.8891
# Epoch 450/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.6531
# Epoch 451/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8400
# Epoch 452/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6639
# Epoch 453/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.4023
# Epoch 454/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.9381
# Epoch 455/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8995
# Epoch 456/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.2649
# Epoch 457/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.1145
# Epoch 458/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3352
# Epoch 459/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.3563
# Epoch 460/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4777
# Epoch 461/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.6451
# Epoch 462/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1994
# Epoch 463/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.6229
# Epoch 464/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6345
# Epoch 465/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.2602
# Epoch 466/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1258
# Epoch 467/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.0472
# Epoch 468/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.0991
# Epoch 469/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 25.5462
# Epoch 470/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 26.9648
# Epoch 471/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.4913
# Epoch 472/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.7046
# Epoch 473/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.4289
# Epoch 474/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.2060
# Epoch 475/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.4092
# Epoch 476/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.3787
# Epoch 477/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0257
# Epoch 478/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.5055
# Epoch 479/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6201
# Epoch 480/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.4023
# Epoch 481/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.7106
# Epoch 482/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.5537
# Epoch 483/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5896
# Epoch 484/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.3320
# Epoch 485/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8758
# Epoch 486/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3508
# Epoch 487/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 31.4951
# Epoch 488/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.3855
# Epoch 489/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 25.4145
# Epoch 490/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.7859
# Epoch 491/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4312
# Epoch 492/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 24.1144
# Epoch 493/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4300
# Epoch 494/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2266
# Epoch 495/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.3259
# Epoch 496/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.5821
# Epoch 497/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 21.1671
# Epoch 498/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 20.6876
# Epoch 499/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3738
# Epoch 500/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.5663
# Epoch 501/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.3220
# Epoch 502/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.4163
# Epoch 503/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.9964
# Epoch 504/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.2556
# Epoch 505/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3008
# Epoch 506/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6878
# Epoch 507/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.3644
# Epoch 508/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.9594
# Epoch 509/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2117
# Epoch 510/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6937
# Epoch 511/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.0333
# Epoch 512/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1519
# Epoch 513/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.2245
# Epoch 514/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.7113
# Epoch 515/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8458
# Epoch 516/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3619
# Epoch 517/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.5571
# Epoch 518/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1926
# Epoch 519/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.7697
# Epoch 520/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.4353
# Epoch 521/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1560
# Epoch 522/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.0772
# Epoch 523/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.3769
# Epoch 524/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8927
# Epoch 525/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4841
# Epoch 526/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.7021
# Epoch 527/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.9417
# Epoch 528/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.4262
# Epoch 529/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9974
# Epoch 530/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.7355
# Epoch 531/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.3738
# Epoch 532/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 26.1676
# Epoch 533/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.7351
# Epoch 534/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3667
# Epoch 535/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4177
# Epoch 536/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2980
# Epoch 537/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 26.8432
# Epoch 538/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.7322
# Epoch 539/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.9400
# Epoch 540/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3600
# Epoch 541/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.7631
# Epoch 542/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 28.3766
# Epoch 543/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.3689
# Epoch 544/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.3934
# Epoch 545/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.9545
# Epoch 546/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9788
# Epoch 547/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.2142
# Epoch 548/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.2426
# Epoch 549/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.0488
# Epoch 550/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 27.6738
# Epoch 551/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 22.5155
# Epoch 552/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.5540
# Epoch 553/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.8166
# Epoch 554/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.8517
# Epoch 555/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 22.9489
# Epoch 556/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.1175
# Epoch 557/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.9400
# Epoch 558/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8177
# Epoch 559/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.8636
# Epoch 560/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.7691
# Epoch 561/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4060
# Epoch 562/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 22.9719
# Epoch 563/1000
# ...
# Epoch 813/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2052
# Epoch 814/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.6312
# Epoch 815/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9155
# Epoch 816/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.3751
# Epoch 817/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.3458
# Epoch 818/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 19.5945
# Epoch 819/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.6167
# Epoch 820/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9399
# Epoch 821/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0324
# Epoch 822/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.0042
# Epoch 823/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6599
# Epoch 824/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.6487
# Epoch 825/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8070
# Epoch 826/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.9769
# Epoch 827/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.2048
# Epoch 828/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.5481
# Epoch 829/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.5718
# Epoch 830/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8724
# Epoch 831/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1562
# Epoch 832/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9358
# Epoch 833/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2142
# Epoch 834/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1581
# Epoch 835/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.2825
# Epoch 836/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2354
# Epoch 837/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0358
# Epoch 838/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.0527
# Epoch 839/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8551
# Epoch 840/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0417
# Epoch 841/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.5722
# Epoch 842/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6512
# Epoch 843/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.0078
# Epoch 844/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.1513
# Epoch 845/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.0192
# Epoch 846/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.4138
# Epoch 847/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5248
# Epoch 848/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.5286
# Epoch 849/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.8552
# Epoch 850/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.0387
# Epoch 851/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.4477
# Epoch 852/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.9200
# Epoch 853/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.5615
# Epoch 854/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1937
# Epoch 855/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.6250
# Epoch 856/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.0440
# Epoch 857/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 19.7639
# Epoch 858/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9264
# Epoch 859/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3982
# Epoch 860/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 19.3528
# Epoch 861/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.6476
# Epoch 862/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.1576
# Epoch 863/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.0883
# Epoch 864/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.6435
# Epoch 865/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.3338
# Epoch 866/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.6865
# Epoch 867/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6114
# Epoch 868/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.4049
# Epoch 869/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 22.1260
# Epoch 870/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 24.6988
# Epoch 871/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8211
# Epoch 872/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.0796
# Epoch 873/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1898
# Epoch 874/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9654
# Epoch 875/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.4944
# Epoch 876/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.6076
# Epoch 877/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.7970
# Epoch 878/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.5453
# Epoch 879/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.1215
# Epoch 880/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.9334
# Epoch 881/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 19.9434
# Epoch 882/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5075
# Epoch 883/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.9078
# Epoch 884/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.8349
# Epoch 885/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.9508
# Epoch 886/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.6208
# Epoch 887/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.3250
# Epoch 888/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.9924
# Epoch 889/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.3594
# Epoch 890/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.1814
# Epoch 891/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0945
# Epoch 892/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.4393
# Epoch 893/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.5427
# Epoch 894/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 19.9946
# Epoch 895/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.0500
# Epoch 896/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9305
# Epoch 897/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.2391
# Epoch 898/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9006
# Epoch 899/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6040
# Epoch 900/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.6350
# Epoch 901/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.5930
# Epoch 902/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8179
# Epoch 903/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0636
# Epoch 904/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 19.9291
# Epoch 905/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.3442
# Epoch 906/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.8118
# Epoch 907/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.6986
# Epoch 908/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2372
# Epoch 909/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1088
# Epoch 910/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.3563
# Epoch 911/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.6342
# Epoch 912/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1840
# Epoch 913/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9085
# Epoch 914/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.6409
# Epoch 915/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 19.8458
# Epoch 916/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.0654
# Epoch 917/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2278
# Epoch 918/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.2236
# Epoch 919/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.7717
# Epoch 920/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2933
# Epoch 921/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.0812
# Epoch 922/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.3006
# Epoch 923/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.5747
# Epoch 924/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.1002
# Epoch 925/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.4301
# Epoch 926/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1968
# Epoch 927/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.9046
# Epoch 928/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.7213
# Epoch 929/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.3792
# Epoch 930/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.7732
# Epoch 931/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.2750
# Epoch 932/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.0844
# Epoch 933/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 18.8940
# Epoch 934/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.9718
# Epoch 935/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.5538
# Epoch 936/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.4152
# Epoch 937/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.9398
# Epoch 938/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.0969
# Epoch 939/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.2340
# Epoch 940/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.3180
# Epoch 941/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.8498
# Epoch 942/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.8509
# Epoch 943/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.8965
# Epoch 944/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.6664
# Epoch 945/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.5569
# Epoch 946/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.2369
# Epoch 947/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.1896
# Epoch 948/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.6736
# Epoch 949/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.4176
# Epoch 950/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 21.3182
# Epoch 951/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.5702
# Epoch 952/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.0109
# Epoch 953/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.3543
# Epoch 954/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.3475
# Epoch 955/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.2585
# Epoch 956/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 25.0255
# Epoch 957/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.2061
# Epoch 958/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.1617
# Epoch 959/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 19.0559
# Epoch 960/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 22.1946
# Epoch 961/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.8255
# Epoch 962/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 21.0448
# Epoch 963/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.0613
# Epoch 964/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.5421
# Epoch 965/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.5103
# Epoch 966/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.8622
# Epoch 967/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.7817
# Epoch 968/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0167
# Epoch 969/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 19.1841
# Epoch 970/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.3072
# Epoch 971/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0314
# Epoch 972/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.2588
# Epoch 973/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 25.4469
# Epoch 974/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.3993
# Epoch 975/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.5562
# Epoch 976/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9796
# Epoch 977/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.9922
# Epoch 978/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 19.6550
# Epoch 979/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.2988
# Epoch 980/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 21.7270
# Epoch 981/1000
# 34/34 [==============================] - 1s 20ms/step - loss: 24.6631
# Epoch 982/1000
# 34/34 [==============================] - 1s 20ms/step - loss: 21.8918
# Epoch 983/1000
# 34/34 [==============================] - 1s 20ms/step - loss: 22.4068
# Epoch 984/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 21.6848
# Epoch 985/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 20.8816
# Epoch 986/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.1617
# Epoch 987/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 26.1465
# Epoch 988/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.7431
# Epoch 989/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.9637
# Epoch 990/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.2426
# Epoch 991/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.9522
# Epoch 992/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.1942
# Epoch 993/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 22.4322
# Epoch 994/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 20.9296
# Epoch 995/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 21.7112
# Epoch 996/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 24.6365
# Epoch 997/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 22.7271
# Epoch 998/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 23.5515
# Epoch 999/1000
# 34/34 [==============================] - 1s 19ms/step - loss: 22.0985
# Epoch 1000/1000
# 34/34 [==============================] - 1s 18ms/step - loss: 23.0013

# %% [markdown]
# # Final Evaluation and Forecasting

# %% [markdown]
# ## Evaluating Final Models (SVR, RFR, Voting)

# %%
# SVR Train Score
y_svr_pred_train = svr_model.predict(X_train_scaled)
r2_svr_train = r2_score(y_train, y_svr_pred_train)
mse_svr_train = mean_squared_error(y_train, y_svr_pred_train)
mae_svr_train = mean_absolute_error(y_train, y_svr_pred_train)

# SVR Test Score
y_svr_pred_test = svr_model.predict(X_test_scaled)
r2_svr_test = r2_score(y_test, y_svr_pred_test)
mse_svr_test = mean_squared_error(y_test, y_svr_pred_test)
mae_svr_test = mean_absolute_error(y_test, y_svr_pred_test)

# RFR Train Score
y_rfr_pred_train = rfr_model.predict(X_train_scaled)
r2_rfr_train = r2_score(y_train, y_rfr_pred_train)
mse_rfr_train = mean_squared_error(y_train, y_rfr_pred_train)
mae_rfr_train = mean_absolute_error(y_train, y_rfr_pred_train)

# RFR Test Score
y_rfr_pred_test = rfr_model.predict(X_test_scaled)
r2_rfr_test = r2_score(y_test, y_rfr_pred_test)
mse_rfr_test = mean_squared_error(y_test, y_rfr_pred_test)
mae_rfr_test = mean_absolute_error(y_test, y_rfr_pred_test)

# Voting Train Score
y_voting_pred_train = voting_model.predict(X_train_scaled)
r2_voting_train = r2_score(y_train, y_voting_pred_train)
mse_voting_train = mean_squared_error(y_train, y_voting_pred_train)
mae_voting_train = mean_absolute_error(y_train, y_voting_pred_train)

# Voting Test Score
y_voting_pred_test = voting_model.predict(X_test_scaled)
r2_voting_test = r2_score(y_test, y_voting_pred_test)
mse_voting_test = mean_squared_error(y_test, y_voting_pred_test)
mae_voting_test = mean_absolute_error(y_test, y_voting_pred_test)

# LSTM Train Score
y_lstm_pred_train = lstm_model.predict(X_train_reshaped)
r2_lstm_train = r2_score(y_train, y_lstm_pred_train)
mse_lstm_train = mean_squared_error(y_train, y_lstm_pred_train)
mae_lstm_train = mean_absolute_error(y_train, y_lstm_pred_train)

# LSTM Test Score
y_lstm_pred_test = lstm_model.predict(X_test_reshaped)
r2_lstm_test = r2_score(y_test, y_lstm_pred_test)
mse_lstm_test = mean_squared_error(y_test, y_lstm_pred_test)
mae_lstm_test = mean_absolute_error(y_test, y_lstm_pred_test)

svr_result = ["SVR (Best)", r2_svr_train, r2_svr_test, mse_svr_train,
            mse_svr_test, mae_svr_train, mae_svr_test]

rfr_result = ["RFR (Best)", r2_rfr_train, r2_rfr_test, mse_rfr_train,
            mse_rfr_test, mae_rfr_train, mae_rfr_test]

voting_result = ["Voting", r2_voting_train, r2_voting_test, mse_voting_train,
            mse_voting_test, mae_voting_train, mae_voting_test]

lstm_result = ["LSTM", r2_lstm_train, r2_lstm_test, mse_lstm_train,
            mse_lstm_test, mae_lstm_train, mae_lstm_test]

result_table = [svr_result, rfr_result, voting_result, lstm_result]
headers = ["Model", "R² (Train)", "R² (Test)","MSE (Train)", "MSE (Test)", "MAE (Train)", "MAE (Test)"]

print(tabulate(result_table, headers=headers, tablefmt="fancy_grid"))
# Out:
# 34/34 [==============================] - 0s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# ╒════════════╤══════════════╤═════════════╤═══════════════╤══════════════╤═══════════════╤══════════════╕
# │ Model      │   R² (Train) │   R² (Test) │   MSE (Train) │   MSE (Test) │   MAE (Train) │   MAE (Test) │
# ╞════════════╪══════════════╪═════════════╪═══════════════╪══════════════╪═══════════════╪══════════════╡
# │ SVR (Best) │     0.999745 │    0.995552 │      0.514242 │     0.884256 │      0.478879 │     0.769306 │
# ├────────────┼──────────────┼─────────────┼───────────────┼──────────────┼───────────────┼──────────────┤
# │ RFR (Best) │     0.999917 │    0.982931 │      0.167751 │     3.39312  │      0.271115 │     1.31051  │
# ├────────────┼──────────────┼─────────────┼───────────────┼──────────────┼───────────────┼──────────────┤
# │ Voting     │     0.999858 │    0.991909 │      0.285429 │     1.60842  │      0.361017 │     0.982035 │
# ├────────────┼──────────────┼─────────────┼───────────────┼──────────────┼───────────────┼──────────────┤
# │ LSTM       │     0.998974 │    0.959544 │      2.06525  │     8.04231  │      0.983883 │     2.01587  │
# ╘════════════╧══════════════╧═════════════╧═══════════════╧══════════════╧═══════════════╧══════════════╛

# %% [markdown]
# ## Cross-Validation

# %%
# Perform cross-validation
# Define the scoring metrics
scoring = ['neg_mean_squared_error', 'neg_mean_absolute_error', 'r2']

# Perform cross-validation and calculate the mean and standard deviation for each scoring metric
cv_results = []

svr_cv_results = ['SVR']
rfr_cv_results = ['RFR']
voting_cv_results = ['Voting']
lstm_cv_results = ['LSTM']

for score in scoring:
    svr_cv_scores = cross_val_score(svr_model, X, y, cv=5, scoring=score)
    rfr_cv_scores = cross_val_score(rfr_model, X, y, cv=5, scoring=score)
    voting_cv_scores = cross_val_score(voting_model, X, y, cv=5, scoring=score)

    if score == 'r2':
        svr_cv_results.append(svr_cv_scores.mean())
        svr_cv_results.append(svr_cv_scores.std())

        rfr_cv_results.append(rfr_cv_scores.mean())
        rfr_cv_results.append(rfr_cv_scores.std())

        voting_cv_results.append(voting_cv_scores.mean())
        voting_cv_results.append(voting_cv_scores.std())
    else:
        svr_cv_results.append(np.abs(svr_cv_scores).mean())
        rfr_cv_results.append(np.abs(rfr_cv_scores).mean())
        voting_cv_results.append(np.abs(voting_cv_scores).mean())

# Define the number of folds for cross-validation
n_splits = 5

# Initialize arrays to store the scores
mse_scores = []
mae_scores = []
r2_scores = []

# Perform cross-validation
kf = KFold(n_splits=n_splits)

for train_index, test_index in kf.split(X):

    X_train_lstm, X_test_lstm = X.iloc[train_index], X.iloc[test_index]
    y_train_lstm, y_test_lstm = y[train_index], y[test_index]

     # Perform feature scaling on the training and validation sets separately
    X_test_lstm_scaled = scaler.transform(X_test_lstm)
    X_test_lstm_reshaped =  np.reshape(X_test_lstm_scaled, (X_test_lstm_scaled.shape[0], X_test_lstm_scaled.shape[1], 1))

    # Evaluate the pre-trained model on the test data
    y_pred_lstm = lstm_model.predict(X_test_lstm_reshaped)

    # Calculate the scores for different metrics
    mse = mean_squared_error(y_test_lstm, y_pred_lstm)
    mae = mean_absolute_error(y_test_lstm, y_pred_lstm)
    r2 = r2_score(y_test_lstm, y_pred_lstm)

    # Append the scores to the respective arrays
    mse_scores.append(mse)
    mae_scores.append(mae)
    r2_scores.append(r2)

# Calculate the mean and standard deviation of MSE, MAE, and R^2 scores
mean_mse = np.mean(mse_scores)
mean_mae = np.mean(mae_scores)
mean_r2 = np.mean(r2_scores)
std_r2 = np.std(r2_scores)

lstm_cv_results.append(mean_mse)
lstm_cv_results.append(mean_mae)
lstm_cv_results.append(mean_r2)
lstm_cv_results.append(std_r2)

cv_results.extend([svr_cv_results, rfr_cv_results, voting_cv_results, lstm_cv_results])

# Create a table to display the cross-validation results
cv_headers = ["Model", "Mean MSE Score", "Mean MAE Score", "Mean R² Score", "R² Standard Deviation"]
print(tabulate(cv_results, headers=cv_headers, tablefmt="fancy_grid"))
# Out:
# 9/9 [==============================] - 0s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# ╒═════════╤══════════════════╤══════════════════╤═════════════════╤═════════════════════════╕
# │ Model   │   Mean MSE Score │   Mean MAE Score │   Mean R² Score │   R² Standard Deviation │
# ╞═════════╪══════════════════╪══════════════════╪═════════════════╪═════════════════════════╡
# │ SVR     │         10.9299  │          2.33159 │        0.932376 │              0.0211155  │
# ├─────────┼──────────────────┼──────────────────┼─────────────────┼─────────────────────────┤
# │ RFR     │         11.1695  │          1.83396 │        0.941469 │              0.0491757  │
# ├─────────┼──────────────────┼──────────────────┼─────────────────┼─────────────────────────┤
# │ Voting  │          4.87263 │          1.45851 │        0.976252 │              0.00975116 │
# ├─────────┼──────────────────┼──────────────────┼─────────────────┼─────────────────────────┤
# │ LSTM    │          3.26066 │          1.19028 │        0.983218 │              0.0128436  │
# ╘═════════╧══════════════════╧══════════════════╧═════════════════╧═════════════════════════╛

# %% [markdown]
# ## Downloading Latest Historical Price Data

# %% [markdown]
# ## Preparing Forecast Data

# %%
last_index_date = df.index[-1]
start_index_date = df.tail(60).index

# Download latest 60 days historical price data from Yahoo Finance and store in a pandas DataFrame
df_actual = yf.download("AAPL", start=start_index_date[0], end=last_index_date, progress=False)

number_of_days = len(df_actual)
last_n_days = df[-number_of_days:]

last_n_days_df = pd.DataFrame(
    last_n_days, columns=X.columns)

X_pred = scaler.transform(last_n_days_df)

y_svr_pred = svr_model.predict(X_pred) 
y_rfr_pred = rfr_model.predict(X_pred)
y_voting_pred = voting_model.predict(X_pred) 

X_pred_reshaped = np.reshape(X_pred, (X_pred.shape[0], X_pred.shape[1], 1))
y_lstm_pred = lstm_model.predict(X_pred_reshaped)

df_pred = pd.DataFrame({'SVR Prediction': y_svr_pred,
                        'RFR Prediction': y_rfr_pred,
                        'Voting Prediction': y_voting_pred,
                        'LSTM Prediction': np.squeeze(y_lstm_pred)}, index=df_actual.index)

df_combined = pd.concat([df_actual, df_pred], axis=1)

forecast_dates = pd.date_range(start=df.index[-1] + pd.DateOffset(days=1), periods=10, freq='B')
df_forecast = pd.DataFrame(index=forecast_dates)

# Get the last available historical data
last_data = X.iloc[-10:, :]  # Get the last 35 data points, assuming each row represents a sample

# Preprocess the forecast data by scaling it using the same scaler used for training
last_data_scaled = scaler.transform(last_data)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %% [markdown]
# ## Making Predictions for Forecast Period using Final Models

# %%
# Make predictions for the forecast period using the SVR and RFR models
svr_prediction = svr_model.predict(last_data_scaled)
rfr_prediction = rfr_model.predict(last_data_scaled)
voting_prediction = voting_model.predict(last_data_scaled)

last_data_scaled_reshaped = np.reshape(last_data_scaled, (last_data_scaled.shape[0], last_data_scaled.shape[1], 1))
lstm_prediction= lstm_model.predict(last_data_scaled_reshaped)

# Assign the forecasted prices to the DataFrame columns
df_forecast['SVR Prediction'] = svr_prediction
df_forecast['RFR Prediction'] = rfr_prediction
df_forecast['Voting Prediction'] = voting_prediction
df_forecast['LSTM Prediction'] = lstm_prediction

# Set the display format for float values
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
# 1/1 [==============================] - 0s 11ms/step

# %% [markdown]
# ## Combining Actual Prices and Forecasted Prices from all models

# %%
df_combined2 = pd.concat([df_combined, df_forecast])

# %% [markdown]
# ## Visualizing Actual Prices and Predictions

# %%
# Plot the actual price and the predictions
plt.figure(figsize=(16, 8))
plt.plot(df_combined2.index, df_combined2['Close'], label='Historical')
plt.plot(df_combined2.index,
        df_combined2['SVR Prediction'], label='SVR Prediction')
plt.plot(df_combined2.index,
        df_combined2['RFR Prediction'], label='RFR Prediction')
plt.plot(df_combined2.index,
        df_combined2['Voting Prediction'], label='Voting Prediction')
plt.plot(df_combined2.index,
        df_combined2['LSTM Prediction'], label='LSTM Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Displaying Forecasted Prices from all models

# %%
# Assuming df_forecast is your DataFrame
table = tabulate(df_forecast, headers='keys', tablefmt='fancy_grid')
print(table)
# Out:
# ╒═════════════════════╤══════════════════╤══════════════════╤═════════════════════╤═══════════════════╕
# │                     │   SVR Prediction │   RFR Prediction │   Voting Prediction │   LSTM Prediction │
# ╞═════════════════════╪══════════════════╪══════════════════╪═════════════════════╪═══════════════════╡
# │ 2023-06-26 00:00:00 │          181.513 │          179.436 │             180.571 │           174.942 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-06-27 00:00:00 │          183.129 │          178.561 │             180.99  │           174.949 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-06-28 00:00:00 │          183.378 │          178.754 │             181.117 │           174.958 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-06-29 00:00:00 │          183.271 │          178.769 │             180.997 │           174.96  │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-06-30 00:00:00 │          185.613 │          179.086 │             182.378 │           174.961 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-03 00:00:00 │          185.085 │          179.223 │             182.184 │           174.953 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-04 00:00:00 │          185.466 │          178.744 │             182.269 │           174.961 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-05 00:00:00 │          183.685 │          178.744 │             181.379 │           174.962 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-06 00:00:00 │          186.291 │          178.744 │             182.681 │           174.961 │
# ├─────────────────────┼──────────────────┼──────────────────┼─────────────────────┼───────────────────┤
# │ 2023-07-07 00:00:00 │          186.309 │          178.744 │             182.69  │           174.953 │
# ╘═════════════════════╧══════════════════╧══════════════════╧═════════════════════╧═══════════════════╛

# %%
import plotly.graph_objects as go

# Create traces
trace_actual = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['Close'],
    mode='lines',
    name='Historical'
)

trace_svr = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['SVR Prediction'],
    mode='lines',
    name='SVR Prediction'
)

trace_rfr = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['RFR Prediction'],
    mode='lines',
    name='RFR Prediction'
)

trace_voting = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['Voting Prediction'],
    mode='lines',
    name='Voting Prediction'
)

trace_lstm = go.Scatter(
    x=df_combined2.index,
    y=df_combined2['LSTM Prediction'],
    mode='lines',
    name='LSTM Prediction'
)

data = [trace_actual, trace_svr, trace_rfr, trace_voting, trace_lstm]

# Create layout
layout = go.Layout(
    title='Actual Price and Predictions',
    xaxis=dict(title='Date'),
    yaxis=dict(title='Price'),
    showlegend=True
)

# Create figure
fig = go.Figure(data=data, layout=layout)

# Show the figure
fig.show()

# %%
import pickle

with open('../dashboard/models/apple/rfr.pkl', 'wb') as f:
    pickle.dump(rfr_model, f)

with open('../dashboard/models/apple/svr.pkl', 'wb') as f:
    pickle.dump(svr_model, f)

with open('../dashboard/models/apple/voting.pkl', 'wb') as f:
    pickle.dump(voting_model, f)

with open('../dashboard/models/apple/lstm.pkl', 'wb') as f:
    pickle.dump(lstm_model, f)

with open('../dashboard/models/apple/scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

df.to_csv('../dashboard/models/apple/df.csv', index=True)
X.to_csv('../dashboard/models/apple/X.csv', index=True)
